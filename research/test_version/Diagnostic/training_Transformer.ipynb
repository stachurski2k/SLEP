# %%
import plotly.graph_objects as go
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import pandas as pd
import plotly.express as px
from sklearn.manifold import TSNE
import colorcet as cc

# %%
# %cd ..
from Models.Transformer_encoder import TransformerEncoder_model
# Out:
# c:\Users\Kayned\Documents\GitHub\SLEP\research\test_version

# %%
from TrainModel.train import training
training(TransformerEncoder_model)
# Out:
# Train: 733 videos | Val: 335 videos | Classes: 32
# c:\Users\Kayned\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ------------------------------------------------------------------------------------------
# Model: TransformerEncoder_model      input= 144      hidden= 256   layers= 2   dropout= 0.4    device= cuda
# Training: epochs= 500    lr= 0.0005    MultiSimilarityLoss: alpha= 2.0 beta= 40.0 base= 0.5
# Batch Train: P = 16 classes x K = 4 = 64 samples
# Batch Val:   P = 16 classes x K = 4 = 64 samples
# ------------------------------------------------------------------------------------------
# Epoch   1 | train: 1.0317 | val: 0.9743 | lr: 4.99e-04 | val_acc: 54.93%  <- best
# Epoch   2 | train: 0.9612 | val: 0.9332 | lr: 4.95e-04 | val_acc: 54.63%
# Epoch   3 | train: 0.9430 | val: 0.9154 | lr: 4.88e-04 | val_acc: 60.00%  <- best
# Epoch   4 | train: 0.9330 | val: 0.8984 | lr: 4.78e-04 | val_acc: 62.09%  <- best
# Epoch   5 | train: 0.9159 | val: 0.8844 | lr: 4.67e-04 | val_acc: 66.57%  <- best
# Epoch   6 | train: 0.9003 | val: 0.9142 | lr: 4.52e-04 | val_acc: 68.06%  <- best
# Epoch   7 | train: 0.9071 | val: 0.9036 | lr: 4.36e-04 | val_acc: 64.78%
# Epoch   8 | train: 0.8913 | val: 0.8931 | lr: 4.17e-04 | val_acc: 67.76%
# Epoch   9 | train: 0.8850 | val: 0.8908 | lr: 3.97e-04 | val_acc: 65.37%
# Epoch  10 | train: 0.8835 | val: 0.8736 | lr: 3.75e-04 | val_acc: 67.76%
# Epoch  11 | train: 0.8694 | val: 0.8511 | lr: 3.52e-04 | val_acc: 71.94%  <- best
# Epoch  12 | train: 0.8591 | val: 0.8457 | lr: 3.28e-04 | val_acc: 72.54%  <- best
# Epoch  13 | train: 0.8230 | val: 0.8354 | lr: 3.02e-04 | val_acc: 74.33%  <- best
# Epoch  14 | train: 0.8356 | val: 0.8423 | lr: 2.77e-04 | val_acc: 72.84%
# Epoch  15 | train: 0.8210 | val: 0.8223 | lr: 2.51e-04 | val_acc: 75.52%  <- best
# Epoch  16 | train: 0.8040 | val: 0.8263 | lr: 2.24e-04 | val_acc: 76.42%  <- best
# Epoch  17 | train: 0.8030 | val: 0.7996 | lr: 1.99e-04 | val_acc: 75.82%
# Epoch  18 | train: 0.7766 | val: 0.8067 | lr: 1.73e-04 | val_acc: 76.72%  <- best
# Epoch  19 | train: 0.7836 | val: 0.7753 | lr: 1.49e-04 | val_acc: 77.61%  <- best
# Epoch  20 | train: 0.7756 | val: 0.8160 | lr: 1.26e-04 | val_acc: 77.01%
# Epoch  21 | train: 0.7768 | val: 0.7537 | lr: 1.04e-04 | val_acc: 77.61%  <- best
# Epoch  22 | train: 0.7765 | val: 0.7873 | lr: 8.36e-05 | val_acc: 78.51%  <- best
# Epoch  23 | train: 0.7298 | val: 0.7867 | lr: 6.51e-05 | val_acc: 78.51%  <- best
# Epoch  24 | train: 0.7364 | val: 0.7669 | lr: 4.87e-05 | val_acc: 77.91%
# Epoch  25 | train: 0.7211 | val: 0.7838 | lr: 3.44e-05 | val_acc: 78.21%
# Epoch  26 | train: 0.7315 | val: 0.7542 | lr: 2.26e-05 | val_acc: 79.10%  <- best
# Epoch  27 | train: 0.7115 | val: 0.7694 | lr: 1.32e-05 | val_acc: 79.10%
# Epoch  28 | train: 0.7124 | val: 0.7552 | lr: 6.45e-06 | val_acc: 79.10%
# Epoch  29 | train: 0.7194 | val: 0.7505 | lr: 2.37e-06 | val_acc: 79.10%  <- best
# Epoch  30 | train: 0.7024 | val: 0.7576 | lr: 5.00e-04 | val_acc: 79.10%
# Epoch  31 | train: 0.7401 | val: 0.7273 | lr: 5.00e-04 | val_acc: 79.70%  <- best
# Epoch  32 | train: 0.7890 | val: 0.7721 | lr: 4.99e-04 | val_acc: 79.40%
# Epoch  33 | train: 0.7983 | val: 0.7614 | lr: 4.97e-04 | val_acc: 80.30%  <- best
# Epoch  34 | train: 0.7649 | val: 0.7846 | lr: 4.95e-04 | val_acc: 80.60%  <- best
# Epoch  35 | train: 0.7634 | val: 0.7821 | lr: 4.91e-04 | val_acc: 80.60%  <- best
# Epoch  36 | train: 0.7865 | val: 0.7718 | lr: 4.88e-04 | val_acc: 80.30%
# Epoch  37 | train: 0.7661 | val: 0.7764 | lr: 4.83e-04 | val_acc: 79.40%
# Epoch  38 | train: 0.7679 | val: 0.7688 | lr: 4.78e-04 | val_acc: 80.60%  <- best
# Epoch  39 | train: 0.7517 | val: 0.7568 | lr: 4.73e-04 | val_acc: 80.60%  <- best
# Epoch  40 | train: 0.7213 | val: 0.7440 | lr: 4.67e-04 | val_acc: 80.30%
# Epoch  41 | train: 0.7154 | val: 0.7455 | lr: 4.60e-04 | val_acc: 80.30%
# Epoch  42 | train: 0.7072 | val: 0.7360 | lr: 4.52e-04 | val_acc: 81.19%  <- best
# Epoch  43 | train: 0.7021 | val: 0.7455 | lr: 4.44e-04 | val_acc: 81.49%  <- best
# Epoch  44 | train: 0.6780 | val: 0.7703 | lr: 4.36e-04 | val_acc: 80.90%
# Epoch  45 | train: 0.6978 | val: 0.7010 | lr: 4.27e-04 | val_acc: 80.90%
# Epoch  46 | train: 0.6930 | val: 0.7333 | lr: 4.17e-04 | val_acc: 81.79%  <- best
# Epoch  47 | train: 0.6694 | val: 0.7360 | lr: 4.08e-04 | val_acc: 81.49%
# Epoch  48 | train: 0.6805 | val: 0.7335 | lr: 3.97e-04 | val_acc: 81.49%
# Epoch  49 | train: 0.6497 | val: 0.7299 | lr: 3.86e-04 | val_acc: 81.49%
# Epoch  50 | train: 0.6596 | val: 0.7374 | lr: 3.75e-04 | val_acc: 80.60%
# Epoch  51 | train: 0.6527 | val: 0.7321 | lr: 3.64e-04 | val_acc: 80.90%
# Epoch  52 | train: 0.6432 | val: 0.7390 | lr: 3.52e-04 | val_acc: 80.60%
# Epoch  53 | train: 0.6045 | val: 0.7325 | lr: 3.40e-04 | val_acc: 80.90%
# Epoch  54 | train: 0.6223 | val: 0.6819 | lr: 3.28e-04 | val_acc: 81.49%
# Epoch  55 | train: 0.6377 | val: 0.7605 | lr: 3.15e-04 | val_acc: 81.79%
# Epoch  56 | train: 0.6082 | val: 0.7370 | lr: 3.02e-04 | val_acc: 81.49%
# Epoch  57 | train: 0.6069 | val: 0.6995 | lr: 2.90e-04 | val_acc: 81.49%
# Epoch  58 | train: 0.5918 | val: 0.7195 | lr: 2.77e-04 | val_acc: 82.39%  <- best
# Epoch  59 | train: 0.6093 | val: 0.7503 | lr: 2.64e-04 | val_acc: 82.39%
# Epoch  60 | train: 0.5890 | val: 0.6962 | lr: 2.51e-04 | val_acc: 81.19%
# Epoch  61 | train: 0.5494 | val: 0.7397 | lr: 2.37e-04 | val_acc: 80.90%
# Epoch  62 | train: 0.5585 | val: 0.6938 | lr: 2.24e-04 | val_acc: 80.90%
# Epoch  63 | train: 0.5569 | val: 0.6766 | lr: 2.11e-04 | val_acc: 82.09%
# Epoch  64 | train: 0.5636 | val: 0.7334 | lr: 1.99e-04 | val_acc: 82.09%
# Epoch  65 | train: 0.5275 | val: 0.6641 | lr: 1.86e-04 | val_acc: 82.69%  <- best
# Epoch  66 | train: 0.5649 | val: 0.6863 | lr: 1.73e-04 | val_acc: 82.69%
# Epoch  67 | train: 0.5569 | val: 0.6798 | lr: 1.61e-04 | val_acc: 82.69%
# Epoch  68 | train: 0.5360 | val: 0.6682 | lr: 1.49e-04 | val_acc: 82.69%
# Epoch  69 | train: 0.5365 | val: 0.7262 | lr: 1.37e-04 | val_acc: 82.69%
# Epoch  70 | train: 0.5260 | val: 0.7144 | lr: 1.26e-04 | val_acc: 82.99%  <- best
# Epoch  71 | train: 0.5093 | val: 0.6979 | lr: 1.15e-04 | val_acc: 83.28%  <- best
# Epoch  72 | train: 0.5389 | val: 0.7182 | lr: 1.04e-04 | val_acc: 82.99%
# Epoch  73 | train: 0.5069 | val: 0.6892 | lr: 9.35e-05 | val_acc: 83.58%  <- best
# Epoch  74 | train: 0.5074 | val: 0.6876 | lr: 8.36e-05 | val_acc: 83.88%  <- best
# Epoch  75 | train: 0.4996 | val: 0.6615 | lr: 7.41e-05 | val_acc: 83.88%  <- best
# Epoch  76 | train: 0.4859 | val: 0.6527 | lr: 6.51e-05 | val_acc: 84.18%  <- best
# Epoch  77 | train: 0.5048 | val: 0.6682 | lr: 5.66e-05 | val_acc: 84.48%  <- best
# Epoch  78 | train: 0.4958 | val: 0.6372 | lr: 4.87e-05 | val_acc: 83.88%
# Epoch  79 | train: 0.4860 | val: 0.7019 | lr: 4.13e-05 | val_acc: 83.88%
# Epoch  80 | train: 0.4842 | val: 0.6838 | lr: 3.44e-05 | val_acc: 83.88%
# Epoch  81 | train: 0.4827 | val: 0.6562 | lr: 2.82e-05 | val_acc: 83.88%
# Epoch  82 | train: 0.4752 | val: 0.6763 | lr: 2.26e-05 | val_acc: 83.88%
# Epoch  83 | train: 0.4790 | val: 0.7108 | lr: 1.76e-05 | val_acc: 83.88%
# Epoch  84 | train: 0.4958 | val: 0.6800 | lr: 1.32e-05 | val_acc: 83.88%
# Epoch  85 | train: 0.4939 | val: 0.6560 | lr: 9.50e-06 | val_acc: 83.88%
# Epoch  86 | train: 0.4894 | val: 0.7057 | lr: 6.45e-06 | val_acc: 83.88%
# Epoch  87 | train: 0.4860 | val: 0.6674 | lr: 4.07e-06 | val_acc: 83.88%
# Epoch  88 | train: 0.4889 | val: 0.6664 | lr: 2.37e-06 | val_acc: 83.88%
# Epoch  89 | train: 0.4679 | val: 0.6649 | lr: 1.34e-06 | val_acc: 83.88%
# Epoch  90 | train: 0.4820 | val: 0.6577 | lr: 5.00e-04 | val_acc: 83.88%
# Epoch  91 | train: 0.5257 | val: 0.6604 | lr: 5.00e-04 | val_acc: 84.18%
# Epoch  92 | train: 0.5857 | val: 0.6557 | lr: 5.00e-04 | val_acc: 84.18%
# Epoch  93 | train: 0.5954 | val: 0.6944 | lr: 4.99e-04 | val_acc: 83.58%
# Epoch  94 | train: 0.5931 | val: 0.6294 | lr: 4.99e-04 | val_acc: 83.88%
# Epoch  95 | train: 0.5993 | val: 0.6748 | lr: 4.98e-04 | val_acc: 84.18%
# Epoch  96 | train: 0.5828 | val: 0.6798 | lr: 4.97e-04 | val_acc: 83.88%
# Epoch  97 | train: 0.6017 | val: 0.6900 | lr: 4.96e-04 | val_acc: 83.88%
# Epoch  98 | train: 0.5894 | val: 0.6492 | lr: 4.95e-04 | val_acc: 84.18%
# Epoch  99 | train: 0.6192 | val: 0.7238 | lr: 4.93e-04 | val_acc: 83.58%
# Epoch 100 | train: 0.5782 | val: 0.6949 | lr: 4.91e-04 | val_acc: 84.18%
# Epoch 101 | train: 0.5872 | val: 0.6770 | lr: 4.90e-04 | val_acc: 83.88%
# Epoch 102 | train: 0.5468 | val: 0.6995 | lr: 4.88e-04 | val_acc: 84.48%
# Epoch 103 | train: 0.5699 | val: 0.6866 | lr: 4.86e-04 | val_acc: 84.48%
# Epoch 104 | train: 0.5693 | val: 0.6854 | lr: 4.83e-04 | val_acc: 84.18%
# Epoch 105 | train: 0.5564 | val: 0.6647 | lr: 4.81e-04 | val_acc: 84.18%
# Epoch 106 | train: 0.5722 | val: 0.6526 | lr: 4.78e-04 | val_acc: 84.48%  <- best
# Epoch 107 | train: 0.5553 | val: 0.6738 | lr: 4.76e-04 | val_acc: 84.48%
# Epoch 108 | train: 0.5506 | val: 0.6239 | lr: 4.73e-04 | val_acc: 84.48%  <- best
# Epoch 109 | train: 0.5531 | val: 0.6681 | lr: 4.70e-04 | val_acc: 84.78%  <- best
# Epoch 110 | train: 0.5464 | val: 0.6778 | lr: 4.67e-04 | val_acc: 84.18%
# Epoch 111 | train: 0.5610 | val: 0.6648 | lr: 4.63e-04 | val_acc: 83.88%
# Epoch 112 | train: 0.5292 | val: 0.6871 | lr: 4.60e-04 | val_acc: 84.78%
# Epoch 113 | train: 0.5160 | val: 0.6524 | lr: 4.56e-04 | val_acc: 84.48%
# Epoch 114 | train: 0.5497 | val: 0.6612 | lr: 4.52e-04 | val_acc: 84.48%
# Epoch 115 | train: 0.5570 | val: 0.6596 | lr: 4.48e-04 | val_acc: 83.88%
# Epoch 116 | train: 0.5355 | val: 0.6409 | lr: 4.44e-04 | val_acc: 84.18%
# Epoch 117 | train: 0.5375 | val: 0.7192 | lr: 4.40e-04 | val_acc: 85.07%  <- best
# Epoch 118 | train: 0.5169 | val: 0.6608 | lr: 4.36e-04 | val_acc: 84.18%
# Epoch 119 | train: 0.5337 | val: 0.6515 | lr: 4.31e-04 | val_acc: 84.18%
# Epoch 120 | train: 0.5596 | val: 0.6461 | lr: 4.27e-04 | val_acc: 85.07%  <- best
# Epoch 121 | train: 0.5073 | val: 0.6107 | lr: 4.22e-04 | val_acc: 84.78%
# Epoch 122 | train: 0.5146 | val: 0.6682 | lr: 4.17e-04 | val_acc: 84.48%
# Epoch 123 | train: 0.5343 | val: 0.6141 | lr: 4.13e-04 | val_acc: 83.58%
# Epoch 124 | train: 0.5178 | val: 0.6365 | lr: 4.08e-04 | val_acc: 83.88%
# Epoch 125 | train: 0.5102 | val: 0.6328 | lr: 4.02e-04 | val_acc: 83.28%
# Epoch 126 | train: 0.5274 | val: 0.6781 | lr: 3.97e-04 | val_acc: 83.58%
# Epoch 127 | train: 0.5200 | val: 0.6563 | lr: 3.92e-04 | val_acc: 84.18%
# Epoch 128 | train: 0.5103 | val: 0.6352 | lr: 3.86e-04 | val_acc: 84.18%
# Epoch 129 | train: 0.4841 | val: 0.6845 | lr: 3.81e-04 | val_acc: 84.18%
# Epoch 130 | train: 0.4926 | val: 0.7235 | lr: 3.75e-04 | val_acc: 84.18%
# Epoch 131 | train: 0.5072 | val: 0.6325 | lr: 3.70e-04 | val_acc: 84.78%
# Epoch 132 | train: 0.5069 | val: 0.6468 | lr: 3.64e-04 | val_acc: 84.78%
# Epoch 133 | train: 0.4965 | val: 0.6378 | lr: 3.58e-04 | val_acc: 85.07%  <- best
# Epoch 134 | train: 0.4909 | val: 0.6588 | lr: 3.52e-04 | val_acc: 85.67%  <- best
# Epoch 135 | train: 0.5019 | val: 0.6469 | lr: 3.46e-04 | val_acc: 85.37%
# Epoch 136 | train: 0.4957 | val: 0.6852 | lr: 3.40e-04 | val_acc: 85.67%
# Epoch 137 | train: 0.4779 | val: 0.7002 | lr: 3.34e-04 | val_acc: 85.67%
# Epoch 138 | train: 0.4735 | val: 0.6403 | lr: 3.28e-04 | val_acc: 85.07%
# Epoch 139 | train: 0.4866 | val: 0.7155 | lr: 3.21e-04 | val_acc: 84.78%
# Epoch 140 | train: 0.4678 | val: 0.6618 | lr: 3.15e-04 | val_acc: 84.78%
# Epoch 141 | train: 0.4712 | val: 0.6670 | lr: 3.09e-04 | val_acc: 84.78%
# Epoch 142 | train: 0.4487 | val: 0.7015 | lr: 3.02e-04 | val_acc: 84.78%
# Epoch 143 | train: 0.4624 | val: 0.6207 | lr: 2.96e-04 | val_acc: 85.37%
# Epoch 144 | train: 0.4831 | val: 0.6525 | lr: 2.90e-04 | val_acc: 85.37%
# Epoch 145 | train: 0.4610 | val: 0.6635 | lr: 2.83e-04 | val_acc: 85.37%
# Epoch 146 | train: 0.4620 | val: 0.6812 | lr: 2.77e-04 | val_acc: 85.07%
# Epoch 147 | train: 0.4442 | val: 0.6675 | lr: 2.70e-04 | val_acc: 85.37%
# Epoch 148 | train: 0.4657 | val: 0.6055 | lr: 2.64e-04 | val_acc: 85.07%
# Epoch 149 | train: 0.4613 | val: 0.6076 | lr: 2.57e-04 | val_acc: 85.07%
# Epoch 150 | train: 0.4544 | val: 0.6642 | lr: 2.51e-04 | val_acc: 84.18%
# Epoch 151 | train: 0.4432 | val: 0.6370 | lr: 2.44e-04 | val_acc: 84.78%
# Epoch 152 | train: 0.4541 | val: 0.6251 | lr: 2.37e-04 | val_acc: 84.48%
# Epoch 153 | train: 0.4498 | val: 0.6701 | lr: 2.31e-04 | val_acc: 84.18%
# Epoch 154 | train: 0.4368 | val: 0.7014 | lr: 2.24e-04 | val_acc: 84.18%
# Epoch 155 | train: 0.4412 | val: 0.6634 | lr: 2.18e-04 | val_acc: 83.88%
# Epoch 156 | train: 0.4351 | val: 0.6688 | lr: 2.11e-04 | val_acc: 84.48%
# Epoch 157 | train: 0.4272 | val: 0.7060 | lr: 2.05e-04 | val_acc: 84.78%
# Epoch 158 | train: 0.4347 | val: 0.6773 | lr: 1.99e-04 | val_acc: 85.07%
# Epoch 159 | train: 0.4315 | val: 0.6525 | lr: 1.92e-04 | val_acc: 85.37%
# Epoch 160 | train: 0.4411 | val: 0.6437 | lr: 1.86e-04 | val_acc: 86.27%  <- best
# Epoch 161 | train: 0.4344 | val: 0.6042 | lr: 1.80e-04 | val_acc: 85.37%
# Epoch 162 | train: 0.4383 | val: 0.6089 | lr: 1.73e-04 | val_acc: 85.67%
# Epoch 163 | train: 0.4214 | val: 0.6803 | lr: 1.67e-04 | val_acc: 85.07%
# Epoch 164 | train: 0.4320 | val: 0.6250 | lr: 1.61e-04 | val_acc: 85.67%
# Epoch 165 | train: 0.4180 | val: 0.6517 | lr: 1.55e-04 | val_acc: 85.67%
# Epoch 166 | train: 0.4219 | val: 0.6137 | lr: 1.49e-04 | val_acc: 85.67%
# Epoch 167 | train: 0.4099 | val: 0.6610 | lr: 1.43e-04 | val_acc: 85.67%
# Epoch 168 | train: 0.4208 | val: 0.6192 | lr: 1.37e-04 | val_acc: 85.37%
# Epoch 169 | train: 0.4068 | val: 0.6367 | lr: 1.31e-04 | val_acc: 85.37%
# Epoch 170 | train: 0.4051 | val: 0.6246 | lr: 1.26e-04 | val_acc: 85.67%
# Epoch 171 | train: 0.4057 | val: 0.6449 | lr: 1.20e-04 | val_acc: 85.97%
# Epoch 172 | train: 0.4139 | val: 0.6594 | lr: 1.15e-04 | val_acc: 85.97%
# Epoch 173 | train: 0.4167 | val: 0.6410 | lr: 1.09e-04 | val_acc: 85.97%
# Epoch 174 | train: 0.4067 | val: 0.6181 | lr: 1.04e-04 | val_acc: 85.67%
# Epoch 175 | train: 0.3989 | val: 0.6483 | lr: 9.86e-05 | val_acc: 85.97%
# Epoch 176 | train: 0.4004 | val: 0.6527 | lr: 9.35e-05 | val_acc: 85.97%
# Epoch 177 | train: 0.4054 | val: 0.6416 | lr: 8.85e-05 | val_acc: 85.67%
# Epoch 178 | train: 0.4056 | val: 0.6147 | lr: 8.36e-05 | val_acc: 85.67%
# Epoch 179 | train: 0.3992 | val: 0.6205 | lr: 7.88e-05 | val_acc: 85.67%
# Epoch 180 | train: 0.4056 | val: 0.6547 | lr: 7.41e-05 | val_acc: 86.27%
# Epoch 181 | train: 0.4037 | val: 0.6617 | lr: 6.95e-05 | val_acc: 85.97%
# Epoch 182 | train: 0.4058 | val: 0.6611 | lr: 6.51e-05 | val_acc: 86.27%
# Epoch 183 | train: 0.4035 | val: 0.6168 | lr: 6.08e-05 | val_acc: 86.27%  <- best
# Epoch 184 | train: 0.3979 | val: 0.6140 | lr: 5.66e-05 | val_acc: 86.27%  <- best
# Epoch 185 | train: 0.3993 | val: 0.6524 | lr: 5.26e-05 | val_acc: 85.97%
# Epoch 186 | train: 0.4095 | val: 0.6889 | lr: 4.87e-05 | val_acc: 85.97%
# Epoch 187 | train: 0.3982 | val: 0.6420 | lr: 4.49e-05 | val_acc: 85.97%
# Epoch 188 | train: 0.3926 | val: 0.6580 | lr: 4.13e-05 | val_acc: 85.67%
# Epoch 189 | train: 0.3977 | val: 0.5863 | lr: 3.78e-05 | val_acc: 85.67%
# Epoch 190 | train: 0.3981 | val: 0.6672 | lr: 3.44e-05 | val_acc: 85.67%
# Epoch 191 | train: 0.4016 | val: 0.6565 | lr: 3.12e-05 | val_acc: 85.67%
# Epoch 192 | train: 0.4019 | val: 0.6401 | lr: 2.82e-05 | val_acc: 85.67%
# Epoch 193 | train: 0.3913 | val: 0.6355 | lr: 2.53e-05 | val_acc: 85.67%
# Epoch 194 | train: 0.3983 | val: 0.6441 | lr: 2.26e-05 | val_acc: 85.67%
# Epoch 195 | train: 0.3944 | val: 0.6339 | lr: 2.00e-05 | val_acc: 85.67%
# Epoch 196 | train: 0.3933 | val: 0.6140 | lr: 1.76e-05 | val_acc: 85.67%
# Epoch 197 | train: 0.3950 | val: 0.6010 | lr: 1.53e-05 | val_acc: 85.67%
# Epoch 198 | train: 0.3929 | val: 0.6995 | lr: 1.32e-05 | val_acc: 85.67%
# Epoch 199 | train: 0.3968 | val: 0.6454 | lr: 1.13e-05 | val_acc: 85.97%
# Epoch 200 | train: 0.3931 | val: 0.6476 | lr: 9.50e-06 | val_acc: 85.67%
# Epoch 201 | train: 0.3933 | val: 0.6436 | lr: 7.89e-06 | val_acc: 85.67%
# Epoch 202 | train: 0.3996 | val: 0.6301 | lr: 6.45e-06 | val_acc: 85.67%
# Epoch 203 | train: 0.4022 | val: 0.6729 | lr: 5.18e-06 | val_acc: 85.97%
# Epoch 204 | train: 0.3996 | val: 0.6403 | lr: 4.07e-06 | val_acc: 85.97%
# Epoch 205 | train: 0.3968 | val: 0.6192 | lr: 3.13e-06 | val_acc: 85.97%
# Epoch 206 | train: 0.3949 | val: 0.6220 | lr: 2.37e-06 | val_acc: 85.97%
# Epoch 207 | train: 0.3903 | val: 0.6447 | lr: 1.77e-06 | val_acc: 85.97%
# Epoch 208 | train: 0.3937 | val: 0.6873 | lr: 1.34e-06 | val_acc: 85.97%
# Epoch 209 | train: 0.3944 | val: 0.7053 | lr: 1.09e-06 | val_acc: 85.97%
# Epoch 210 | train: 0.3960 | val: 0.6291 | lr: 5.00e-04 | val_acc: 85.97%
# Epoch 211 | train: 0.4123 | val: 0.6525 | lr: 5.00e-04 | val_acc: 85.97%
# Epoch 212 | train: 0.4472 | val: 0.6113 | lr: 5.00e-04 | val_acc: 86.27%  <- best
# Epoch 213 | train: 0.4761 | val: 0.6537 | lr: 5.00e-04 | val_acc: 85.07%
# Epoch 214 | train: 0.4938 | val: 0.6088 | lr: 5.00e-04 | val_acc: 85.37%
# Epoch 215 | train: 0.5089 | val: 0.6719 | lr: 4.99e-04 | val_acc: 85.67%
# Epoch 216 | train: 0.4903 | val: 0.6674 | lr: 4.99e-04 | val_acc: 85.67%
# Epoch 217 | train: 0.5288 | val: 0.6546 | lr: 4.99e-04 | val_acc: 85.97%
# Epoch 218 | train: 0.5018 | val: 0.6531 | lr: 4.99e-04 | val_acc: 86.27%
# Epoch 219 | train: 0.5127 | val: 0.6800 | lr: 4.98e-04 | val_acc: 86.27%
# Epoch 220 | train: 0.5059 | val: 0.6496 | lr: 4.98e-04 | val_acc: 85.97%
# Epoch 221 | train: 0.4988 | val: 0.6581 | lr: 4.97e-04 | val_acc: 85.67%
# Epoch 222 | train: 0.5012 | val: 0.6672 | lr: 4.97e-04 | val_acc: 85.67%
# Epoch 223 | train: 0.4581 | val: 0.7160 | lr: 4.96e-04 | val_acc: 85.67%
# Epoch 224 | train: 0.4783 | val: 0.7078 | lr: 4.96e-04 | val_acc: 85.67%
# Epoch 225 | train: 0.4918 | val: 0.6543 | lr: 4.95e-04 | val_acc: 83.88%
# Epoch 226 | train: 0.4979 | val: 0.6901 | lr: 4.95e-04 | val_acc: 82.99%
# Epoch 227 | train: 0.4717 | val: 0.6849 | lr: 4.94e-04 | val_acc: 84.18%
# Epoch 228 | train: 0.5204 | val: 0.6960 | lr: 4.93e-04 | val_acc: 84.18%
# Epoch 229 | train: 0.5109 | val: 0.6120 | lr: 4.92e-04 | val_acc: 83.58%
# Epoch 230 | train: 0.5163 | val: 0.6997 | lr: 4.91e-04 | val_acc: 83.28%
# Epoch 231 | train: 0.4799 | val: 0.7040 | lr: 4.91e-04 | val_acc: 82.99%
# Epoch 232 | train: 0.4880 | val: 0.6696 | lr: 4.90e-04 | val_acc: 82.99%
# Epoch 233 | train: 0.4725 | val: 0.6154 | lr: 4.89e-04 | val_acc: 82.99%
# Epoch 234 | train: 0.4913 | val: 0.5988 | lr: 4.88e-04 | val_acc: 83.58%
# Epoch 235 | train: 0.5038 | val: 0.6738 | lr: 4.87e-04 | val_acc: 83.58%
# Epoch 236 | train: 0.4717 | val: 0.5835 | lr: 4.86e-04 | val_acc: 84.18%
# Epoch 237 | train: 0.4552 | val: 0.6606 | lr: 4.85e-04 | val_acc: 84.48%
# Epoch 238 | train: 0.4549 | val: 0.6723 | lr: 4.83e-04 | val_acc: 84.48%
# Epoch 239 | train: 0.4895 | val: 0.6717 | lr: 4.82e-04 | val_acc: 85.37%
# Epoch 240 | train: 0.5082 | val: 0.6564 | lr: 4.81e-04 | val_acc: 85.67%
# Epoch 241 | train: 0.5009 | val: 0.6772 | lr: 4.80e-04 | val_acc: 85.37%
# Epoch 242 | train: 0.4967 | val: 0.6093 | lr: 4.78e-04 | val_acc: 85.37%
# Epoch 243 | train: 0.4739 | val: 0.6242 | lr: 4.77e-04 | val_acc: 85.07%
# Epoch 244 | train: 0.4489 | val: 0.6421 | lr: 4.76e-04 | val_acc: 85.07%
# Epoch 245 | train: 0.4466 | val: 0.6201 | lr: 4.74e-04 | val_acc: 85.37%
# Epoch 246 | train: 0.4862 | val: 0.6300 | lr: 4.73e-04 | val_acc: 85.67%
# Epoch 247 | train: 0.4774 | val: 0.6897 | lr: 4.71e-04 | val_acc: 85.67%
# Epoch 248 | train: 0.5120 | val: 0.6392 | lr: 4.70e-04 | val_acc: 86.27%
# Epoch 249 | train: 0.4585 | val: 0.6282 | lr: 4.68e-04 | val_acc: 86.87%  <- best
# Epoch 250 | train: 0.4656 | val: 0.6223 | lr: 4.67e-04 | val_acc: 86.27%
# Epoch 251 | train: 0.4973 | val: 0.6331 | lr: 4.65e-04 | val_acc: 85.97%
# Epoch 252 | train: 0.4499 | val: 0.6392 | lr: 4.63e-04 | val_acc: 85.97%
# Epoch 253 | train: 0.4855 | val: 0.6715 | lr: 4.62e-04 | val_acc: 85.07%
# Epoch 254 | train: 0.4619 | val: 0.6534 | lr: 4.60e-04 | val_acc: 85.07%
# Epoch 255 | train: 0.4972 | val: 0.6814 | lr: 4.58e-04 | val_acc: 85.67%
# Epoch 256 | train: 0.4646 | val: 0.6480 | lr: 4.56e-04 | val_acc: 86.27%
# Epoch 257 | train: 0.4546 | val: 0.6658 | lr: 4.54e-04 | val_acc: 86.87%
# Epoch 258 | train: 0.4554 | val: 0.6606 | lr: 4.52e-04 | val_acc: 86.57%
# Epoch 259 | train: 0.4472 | val: 0.6289 | lr: 4.50e-04 | val_acc: 86.27%
# Epoch 260 | train: 0.4712 | val: 0.6251 | lr: 4.48e-04 | val_acc: 86.27%
# Epoch 261 | train: 0.4894 | val: 0.6466 | lr: 4.46e-04 | val_acc: 86.27%
# Epoch 262 | train: 0.4577 | val: 0.6739 | lr: 4.44e-04 | val_acc: 85.67%
# Epoch 263 | train: 0.4838 | val: 0.7368 | lr: 4.42e-04 | val_acc: 85.97%
# Epoch 264 | train: 0.4595 | val: 0.6467 | lr: 4.40e-04 | val_acc: 85.97%
# Epoch 265 | train: 0.4668 | val: 0.7088 | lr: 4.38e-04 | val_acc: 86.57%
# Epoch 266 | train: 0.4476 | val: 0.6633 | lr: 4.36e-04 | val_acc: 86.27%
# Epoch 267 | train: 0.4376 | val: 0.6450 | lr: 4.34e-04 | val_acc: 85.97%
# Epoch 268 | train: 0.4203 | val: 0.5851 | lr: 4.31e-04 | val_acc: 85.37%
# Epoch 269 | train: 0.4273 | val: 0.6030 | lr: 4.29e-04 | val_acc: 85.07%
# Epoch 270 | train: 0.4353 | val: 0.6418 | lr: 4.27e-04 | val_acc: 85.67%
# Epoch 271 | train: 0.4568 | val: 0.6528 | lr: 4.25e-04 | val_acc: 85.67%
# Epoch 272 | train: 0.4733 | val: 0.6601 | lr: 4.22e-04 | val_acc: 85.67%
# Epoch 273 | train: 0.4545 | val: 0.6380 | lr: 4.20e-04 | val_acc: 85.37%
# Epoch 274 | train: 0.4794 | val: 0.6565 | lr: 4.17e-04 | val_acc: 85.37%
# Epoch 275 | train: 0.4293 | val: 0.6531 | lr: 4.15e-04 | val_acc: 85.37%
# Epoch 276 | train: 0.4358 | val: 0.6664 | lr: 4.13e-04 | val_acc: 85.67%
# Epoch 277 | train: 0.4676 | val: 0.6332 | lr: 4.10e-04 | val_acc: 85.97%
# Epoch 278 | train: 0.4463 | val: 0.6583 | lr: 4.08e-04 | val_acc: 86.57%
# Epoch 279 | train: 0.4301 | val: 0.6291 | lr: 4.05e-04 | val_acc: 86.57%
# Epoch 280 | train: 0.4509 | val: 0.6383 | lr: 4.02e-04 | val_acc: 85.97%
# Epoch 281 | train: 0.4309 | val: 0.6272 | lr: 4.00e-04 | val_acc: 86.27%
# Epoch 282 | train: 0.4656 | val: 0.6247 | lr: 3.97e-04 | val_acc: 85.67%
# Epoch 283 | train: 0.4504 | val: 0.6744 | lr: 3.94e-04 | val_acc: 86.27%
# Epoch 284 | train: 0.4474 | val: 0.6227 | lr: 3.92e-04 | val_acc: 85.97%
# Epoch 285 | train: 0.4297 | val: 0.6876 | lr: 3.89e-04 | val_acc: 86.57%
# Epoch 286 | train: 0.4158 | val: 0.6357 | lr: 3.86e-04 | val_acc: 86.57%
# Epoch 287 | train: 0.4300 | val: 0.6609 | lr: 3.84e-04 | val_acc: 86.57%
# Epoch 288 | train: 0.4279 | val: 0.6347 | lr: 3.81e-04 | val_acc: 86.27%
# Epoch 289 | train: 0.4222 | val: 0.5840 | lr: 3.78e-04 | val_acc: 86.27%
# Epoch 290 | train: 0.4402 | val: 0.6422 | lr: 3.75e-04 | val_acc: 86.87%
# Epoch 291 | train: 0.4264 | val: 0.6564 | lr: 3.72e-04 | val_acc: 86.57%
# Epoch 292 | train: 0.4031 | val: 0.6105 | lr: 3.70e-04 | val_acc: 87.16%  <- best
# Epoch 293 | train: 0.4097 | val: 0.6586 | lr: 3.67e-04 | val_acc: 86.27%
# Epoch 294 | train: 0.4187 | val: 0.5909 | lr: 3.64e-04 | val_acc: 86.27%
# Epoch 295 | train: 0.4089 | val: 0.6556 | lr: 3.61e-04 | val_acc: 86.27%
# Epoch 296 | train: 0.4054 | val: 0.6680 | lr: 3.58e-04 | val_acc: 85.97%
# Epoch 297 | train: 0.4227 | val: 0.6138 | lr: 3.55e-04 | val_acc: 85.97%
# Epoch 298 | train: 0.4172 | val: 0.6457 | lr: 3.52e-04 | val_acc: 86.27%
# Epoch 299 | train: 0.4311 | val: 0.6006 | lr: 3.49e-04 | val_acc: 86.57%
# Epoch 300 | train: 0.4222 | val: 0.6103 | lr: 3.46e-04 | val_acc: 86.57%
# Epoch 301 | train: 0.4208 | val: 0.6403 | lr: 3.43e-04 | val_acc: 86.27%
# Epoch 302 | train: 0.4126 | val: 0.6329 | lr: 3.40e-04 | val_acc: 86.27%
# Epoch 303 | train: 0.4097 | val: 0.6547 | lr: 3.37e-04 | val_acc: 85.97%
# Epoch 304 | train: 0.4332 | val: 0.6488 | lr: 3.34e-04 | val_acc: 85.97%
# Epoch 305 | train: 0.4205 | val: 0.5967 | lr: 3.31e-04 | val_acc: 85.97%
# Epoch 306 | train: 0.4175 | val: 0.6486 | lr: 3.28e-04 | val_acc: 85.97%
# Epoch 307 | train: 0.4002 | val: 0.6620 | lr: 3.24e-04 | val_acc: 86.27%
# Epoch 308 | train: 0.4070 | val: 0.6609 | lr: 3.21e-04 | val_acc: 86.27%
# Epoch 309 | train: 0.4001 | val: 0.6364 | lr: 3.18e-04 | val_acc: 86.87%
# Epoch 310 | train: 0.3965 | val: 0.6165 | lr: 3.15e-04 | val_acc: 86.57%
# Epoch 311 | train: 0.4151 | val: 0.6435 | lr: 3.12e-04 | val_acc: 86.27%
# Epoch 312 | train: 0.4089 | val: 0.6408 | lr: 3.09e-04 | val_acc: 86.57%
# Epoch 313 | train: 0.4095 | val: 0.6092 | lr: 3.06e-04 | val_acc: 86.27%
# Epoch 314 | train: 0.4340 | val: 0.6573 | lr: 3.02e-04 | val_acc: 85.97%
# Epoch 315 | train: 0.4047 | val: 0.7096 | lr: 2.99e-04 | val_acc: 86.27%
# Epoch 316 | train: 0.4136 | val: 0.6518 | lr: 2.96e-04 | val_acc: 85.97%
# Epoch 317 | train: 0.4079 | val: 0.6981 | lr: 2.93e-04 | val_acc: 86.27%
# Epoch 318 | train: 0.3990 | val: 0.6623 | lr: 2.90e-04 | val_acc: 86.27%
# Epoch 319 | train: 0.3982 | val: 0.6900 | lr: 2.86e-04 | val_acc: 85.97%
# Epoch 320 | train: 0.4043 | val: 0.6801 | lr: 2.83e-04 | val_acc: 86.27%
# Epoch 321 | train: 0.3933 | val: 0.7042 | lr: 2.80e-04 | val_acc: 85.97%
# Epoch 322 | train: 0.3926 | val: 0.6530 | lr: 2.77e-04 | val_acc: 85.97%
# Epoch 323 | train: 0.4002 | val: 0.6524 | lr: 2.73e-04 | val_acc: 85.67%
# Epoch 324 | train: 0.3957 | val: 0.6793 | lr: 2.70e-04 | val_acc: 85.97%
# Epoch 325 | train: 0.4102 | val: 0.7090 | lr: 2.67e-04 | val_acc: 85.37%
# Epoch 326 | train: 0.3924 | val: 0.6265 | lr: 2.64e-04 | val_acc: 85.37%
# Epoch 327 | train: 0.4017 | val: 0.6244 | lr: 2.60e-04 | val_acc: 85.07%
# Epoch 328 | train: 0.4134 | val: 0.6416 | lr: 2.57e-04 | val_acc: 84.78%
# Epoch 329 | train: 0.3943 | val: 0.6773 | lr: 2.54e-04 | val_acc: 84.48%
# Epoch 330 | train: 0.3925 | val: 0.6226 | lr: 2.51e-04 | val_acc: 84.78%
# Epoch 331 | train: 0.3900 | val: 0.6488 | lr: 2.47e-04 | val_acc: 84.48%
# Epoch 332 | train: 0.3908 | val: 0.6792 | lr: 2.44e-04 | val_acc: 84.18%
# Epoch 333 | train: 0.4007 | val: 0.6616 | lr: 2.41e-04 | val_acc: 83.88%
# Epoch 334 | train: 0.3997 | val: 0.6342 | lr: 2.37e-04 | val_acc: 84.48%
# Epoch 335 | train: 0.3939 | val: 0.6511 | lr: 2.34e-04 | val_acc: 84.18%
# Epoch 336 | train: 0.3904 | val: 0.6541 | lr: 2.31e-04 | val_acc: 84.18%
# Epoch 337 | train: 0.3910 | val: 0.6778 | lr: 2.28e-04 | val_acc: 84.18%
# Epoch 338 | train: 0.3871 | val: 0.6072 | lr: 2.24e-04 | val_acc: 84.48%
# Epoch 339 | train: 0.4037 | val: 0.6820 | lr: 2.21e-04 | val_acc: 84.48%
# Epoch 340 | train: 0.3931 | val: 0.6247 | lr: 2.18e-04 | val_acc: 85.07%
# Epoch 341 | train: 0.3904 | val: 0.6372 | lr: 2.15e-04 | val_acc: 84.78%
# Epoch 342 | train: 0.3851 | val: 0.6614 | lr: 2.11e-04 | val_acc: 85.07%
#
# ------------------------------------------------------------------------------------------
# Early stopping at epoch 342
# ------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------
# Training completed
#
# Best epoch:         292
# Best val loss:      0.6105
# Best val accuracy:  87.16%
#
# Best train distances: d_pos=0.1667 | d_neg=1.4271 | diff=1.2604
# Best val distances:   d_pos=0.4928 | d_neg=1.3975 | diff=0.9047
#
# Data saved in directory: Models\TransformerEncoder_model_Checkpoints

# %%
model_name = TransformerEncoder_model.__name__

logs = np.load(f"Models/{model_name}_Checkpoints/training_logs.npz", allow_pickle=True)
train = np.load(f"Models/{model_name}_Checkpoints/train_embeddings.npz", allow_pickle=True)
val   = np.load(f"Models/{model_name}_Checkpoints/val_embeddings.npz", allow_pickle=True)

# %%
best_epoch = int(logs["best_epoch"])
best_val_loss = float(logs["best_val_loss"])
best_val_accuracy = float(logs["best_val_accuracy"])
best_train_dist = logs["best_train_dists"]
best_val_dist = logs["best_val_dists"]

print(f"Best epoch: {best_epoch}")
print(f"Best val loss: {best_val_loss:.4f}")
print(f"Best val accuracy: {best_val_accuracy:.2%}")
print()
print(f"Best train distance:")
print(f"Positive: {best_train_dist[0]}")
print(f"Negative: {best_train_dist[1]}")
print(f"Difference: {best_train_dist[2]}")
print()
print(f"Best validation distance:")
print(f"Positive: {best_val_dist[0]}")
print(f"Negative: {best_val_dist[1]}")
print(f"Difference: {best_val_dist[2]}")
# Out:
# Best epoch: 292
# Best val loss: 0.6105
# Best val accuracy: 87.16%
#
# Best train distance:
# Positive: 0.16665607690811157
# Negative: 1.4270901679992676
# Difference: 1.2604340314865112
#
# Best validation distance:
# Positive: 0.4927976727485657
# Negative: 1.3975306749343872
# Difference: 0.9047329425811768

# %%
epochs = logs["epochs"]
train_loss = logs["train_loss"]
val_loss = logs["val_loss"]
val_acc = logs["val_acc"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_loss, mode="lines", name="Train Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_loss, mode="lines", name="Val Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_acc, mode="lines", name="Val Accuracy"))

fig.update_layout(
    title="LSTM Training Metrics over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Values",
    hovermode="x unified"
)

fig.show()

# %%
embeddings = train["last_embeddings"]
labels = train["labels"]
id_to_label = train["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Train Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
embeddings = val["last_embeddings"]
labels = val["labels"]
id_to_label = val["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Validation Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
y_true = logs["best_labels"]
y_pred = logs["best_prediction"]

labels_names = val["id_to_label"]
labels_ids = np.arange(len(labels_names))

cm = confusion_matrix(y_true, y_pred, labels=labels_ids)
cm_norm = cm / cm.sum(axis=1, keepdims=True)

fig = go.Figure(data=go.Heatmap(
    z = cm_norm,
    zmin = 0,
    zmax = 1,
    x = labels_names,
    y = labels_names,
    colorscale="turbo",
    text=cm,
    texttemplate="%{text}",
    hovertemplate="True: %{y}<br>Pred: %{x}<extra></extra>"
))

fig.update_layout(
    title="Prediction in Best Epoch",
    xaxis_title="Predicted label",
    yaxis_title="True label",
    width=1200,
    height=1000,
    margin=dict(l=150, r=50, t=80, b=150)
)

fig.show()

# %%
loss_gap = val_loss - train_loss

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=loss_gap, mode="lines", name="Val Loss - Train Loss"))

fig.update_layout(
    title="Loss Gap over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Loss gap",
    hovermode="x unified"
)

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    labels=labels_ids,
    target_names=labels_names,
    zero_division=0
))
# Out:
#               precision    recall  f1-score   support
#
#   BASKETBALL       0.92      0.92      0.92        13
#          BEE       0.83      0.83      0.83        12
#    BREAKFAST       0.75      0.75      0.75        12
#         CALL       0.80      0.89      0.84         9
#          CAR       1.00      1.00      1.00         9
#        CAT 3       0.88      0.78      0.82         9
#    CHRISTMAS       0.83      0.83      0.83        12
#         DEAF       1.00      0.83      0.91        12
#          DOG       0.74      1.00      0.85        14
#          EAT       0.92      1.00      0.96        12
#      FIREMAN       0.88      0.78      0.82         9
#         FISH       1.00      0.78      0.88         9
#     FOOTBALL       1.00      1.00      1.00         9
#        GREEN       0.82      0.90      0.86        10
#         HEAD       0.75      1.00      0.86         9
#     HOSPITAL       0.82      0.75      0.78        12
#          KID       1.00      1.00      1.00         9
#        LUNCH       0.83      0.42      0.56        12
#          MAN       0.90      1.00      0.95         9
#     MECHANIC       1.00      1.00      1.00        12
#      MORNING       0.75      0.90      0.82        10
#        NIGHT       0.90      0.75      0.82        12
#           NO       0.67      0.89      0.76         9
#         NOON       0.80      0.67      0.73        12
#          RED       0.91      1.00      0.95        10
#        SMILE       0.89      0.89      0.89         9
#      STUDENT       1.00      0.78      0.88         9
#         TRIP       0.86      1.00      0.92        12
#   UNIVERSITY       1.00      0.90      0.95        10
#        VALUE       1.00      0.78      0.88         9
#        WOMAN       0.91      1.00      0.95        10
#          YES       0.90      1.00      0.95         9
#
#     accuracy                           0.87       335
#    macro avg       0.88      0.88      0.87       335
# weighted avg       0.88      0.87      0.87       335

# %%
from sklearn.metrics import recall_score

recalls = recall_score(
    y_true,
    y_pred,
    labels=labels_ids,
    average=None,
    zero_division=0
)

order = np.argsort(recalls)

fig = go.Figure(go.Bar(
    x=recalls[order],
    y=labels_names[order],
    orientation="h"
))

fig.update_layout(
    title="Recall per Class",
    xaxis_title="Recall",
    yaxis_title="Class",
    width=1000,
    height=800,
)

fig.show()

# %%
train_dists_mean = logs["train_dists"]
val_dists_mean = logs["val_dists"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 0], mode="lines", name="Train Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 1], mode="lines", name="Train Negative Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 0], mode="lines", name="Val Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 1], mode="lines", name="Val Negative Distance"))

fig.update_layout(
    title="Embedding Distances over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 2], mode="lines", name="Train Difference"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 2], mode="lines", name="Val Difference"))

fig.update_layout(
    title="Embedding Distances between Positive and Negative Samples over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
lr = logs["lr"]

fig = go.Figure()

fig.add_trace(go.Scatter(x=epochs, y=lr, mode="lines", name="Train Loss"))

fig.update_layout(
    title="Learning Rate over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Learnig Rate",
    hovermode="x unified",
)

fig.show()

# %%
val.close()
train.close()
logs.close()
