# %%
import plotly.graph_objects as go
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import pandas as pd
import plotly.express as px
from sklearn.manifold import TSNE
import colorcet as cc

# %%
# %cd ..
from Models.Transformer_encoder import TransformerEncoder
# Out:
# c:\Users\Kayned\Documents\GitHub\SLEP\research\test_version

# %%
from TrainModel.train import training
training(TransformerEncoder)
# Out:
# Train: 733 videos | Val: 335 videos | Classes: 32
# c:\Users\Kayned\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ------------------------------------------------------------------------------------------
# Model: TransformerEncoder      input= 144      hidden= 256   layers= 2   dropout= 0.4    device= cuda
# Training: epochs= 500    lr= 0.0005    MultiSimilarityLoss: alpha= 2.0 beta= 40.0 base= 0.5
# Batch Train: P = 16 classes x K = 4 = 64 samples
# Batch Val:   P = 16 classes x K = 4 = 64 samples
# ------------------------------------------------------------------------------------------
# Epoch   1 | train: 1.0229 | val: 0.9309 | lr: 4.99e-04 | val_acc: 57.61%  <- best
# Epoch   2 | train: 0.9398 | val: 0.9106 | lr: 4.95e-04 | val_acc: 62.09%  <- best
# Epoch   3 | train: 0.9209 | val: 0.8869 | lr: 4.88e-04 | val_acc: 67.46%  <- best
# Epoch   4 | train: 0.9035 | val: 0.8639 | lr: 4.78e-04 | val_acc: 67.46%  <- best
# Epoch   5 | train: 0.8843 | val: 0.8379 | lr: 4.67e-04 | val_acc: 68.36%  <- best
# Epoch   6 | train: 0.8705 | val: 0.8871 | lr: 4.52e-04 | val_acc: 69.25%  <- best
# Epoch   7 | train: 0.8719 | val: 0.8552 | lr: 4.36e-04 | val_acc: 71.34%  <- best
# Epoch   8 | train: 0.8522 | val: 0.8645 | lr: 4.17e-04 | val_acc: 74.03%  <- best
# Epoch   9 | train: 0.8452 | val: 0.8471 | lr: 3.97e-04 | val_acc: 71.64%
# Epoch  10 | train: 0.8257 | val: 0.8309 | lr: 3.75e-04 | val_acc: 71.94%
# Epoch  11 | train: 0.8262 | val: 0.7976 | lr: 3.52e-04 | val_acc: 75.82%  <- best
# Epoch  12 | train: 0.8184 | val: 0.8044 | lr: 3.28e-04 | val_acc: 77.91%  <- best
# Epoch  13 | train: 0.7852 | val: 0.7883 | lr: 3.02e-04 | val_acc: 77.61%
# Epoch  14 | train: 0.8109 | val: 0.8016 | lr: 2.77e-04 | val_acc: 77.01%
# Epoch  15 | train: 0.7877 | val: 0.7704 | lr: 2.51e-04 | val_acc: 78.51%  <- best
# Epoch  16 | train: 0.7766 | val: 0.7893 | lr: 2.24e-04 | val_acc: 80.30%  <- best
# Epoch  17 | train: 0.7692 | val: 0.7435 | lr: 1.99e-04 | val_acc: 80.30%  <- best
# Epoch  18 | train: 0.7528 | val: 0.7636 | lr: 1.73e-04 | val_acc: 79.10%
# Epoch  19 | train: 0.7571 | val: 0.7353 | lr: 1.49e-04 | val_acc: 80.90%  <- best
# Epoch  20 | train: 0.7404 | val: 0.7633 | lr: 1.26e-04 | val_acc: 80.00%
# Epoch  21 | train: 0.7544 | val: 0.7265 | lr: 1.04e-04 | val_acc: 82.39%  <- best
# Epoch  22 | train: 0.7523 | val: 0.7413 | lr: 8.36e-05 | val_acc: 81.49%
# Epoch  23 | train: 0.7187 | val: 0.7604 | lr: 6.51e-05 | val_acc: 83.88%  <- best
# Epoch  24 | train: 0.7268 | val: 0.7248 | lr: 4.87e-05 | val_acc: 82.69%
# Epoch  25 | train: 0.7132 | val: 0.7412 | lr: 3.44e-05 | val_acc: 82.99%
# Epoch  26 | train: 0.7232 | val: 0.7173 | lr: 2.26e-05 | val_acc: 82.09%
# Epoch  27 | train: 0.6970 | val: 0.7296 | lr: 1.32e-05 | val_acc: 83.28%
# Epoch  28 | train: 0.7085 | val: 0.7005 | lr: 6.45e-06 | val_acc: 82.99%
# Epoch  29 | train: 0.7085 | val: 0.7198 | lr: 2.37e-06 | val_acc: 83.28%
# Epoch  30 | train: 0.6955 | val: 0.7183 | lr: 5.00e-04 | val_acc: 83.28%
# Epoch  31 | train: 0.7268 | val: 0.6925 | lr: 5.00e-04 | val_acc: 82.99%
# Epoch  32 | train: 0.7471 | val: 0.7314 | lr: 4.99e-04 | val_acc: 82.69%
# Epoch  33 | train: 0.7530 | val: 0.7054 | lr: 4.97e-04 | val_acc: 83.28%
# Epoch  34 | train: 0.7399 | val: 0.7341 | lr: 4.95e-04 | val_acc: 84.18%  <- best
# Epoch  35 | train: 0.7320 | val: 0.7503 | lr: 4.91e-04 | val_acc: 84.18%
# Epoch  36 | train: 0.7431 | val: 0.7091 | lr: 4.88e-04 | val_acc: 84.18%  <- best
# Epoch  37 | train: 0.7283 | val: 0.7282 | lr: 4.83e-04 | val_acc: 84.48%  <- best
# Epoch  38 | train: 0.7234 | val: 0.7022 | lr: 4.78e-04 | val_acc: 83.28%
# Epoch  39 | train: 0.7267 | val: 0.7067 | lr: 4.73e-04 | val_acc: 83.28%
# Epoch  40 | train: 0.7193 | val: 0.6946 | lr: 4.67e-04 | val_acc: 83.28%
# Epoch  41 | train: 0.7117 | val: 0.7020 | lr: 4.60e-04 | val_acc: 84.48%  <- best
# Epoch  42 | train: 0.6896 | val: 0.6953 | lr: 4.52e-04 | val_acc: 83.88%
# Epoch  43 | train: 0.6803 | val: 0.6918 | lr: 4.44e-04 | val_acc: 82.99%
# Epoch  44 | train: 0.6797 | val: 0.7249 | lr: 4.36e-04 | val_acc: 82.99%
# Epoch  45 | train: 0.6857 | val: 0.6667 | lr: 4.27e-04 | val_acc: 83.58%
# Epoch  46 | train: 0.6761 | val: 0.6928 | lr: 4.17e-04 | val_acc: 82.99%
# Epoch  47 | train: 0.6409 | val: 0.6784 | lr: 4.08e-04 | val_acc: 82.99%
# Epoch  48 | train: 0.6576 | val: 0.6809 | lr: 3.97e-04 | val_acc: 82.99%
# Epoch  49 | train: 0.6428 | val: 0.6687 | lr: 3.86e-04 | val_acc: 83.58%
# Epoch  50 | train: 0.6489 | val: 0.6792 | lr: 3.75e-04 | val_acc: 83.58%
# Epoch  51 | train: 0.6308 | val: 0.6939 | lr: 3.64e-04 | val_acc: 83.28%
# Epoch  52 | train: 0.6437 | val: 0.6936 | lr: 3.52e-04 | val_acc: 82.99%
# Epoch  53 | train: 0.6056 | val: 0.6586 | lr: 3.40e-04 | val_acc: 83.88%
# Epoch  54 | train: 0.6248 | val: 0.6418 | lr: 3.28e-04 | val_acc: 84.18%
# Epoch  55 | train: 0.6122 | val: 0.7213 | lr: 3.15e-04 | val_acc: 83.58%
# Epoch  56 | train: 0.6207 | val: 0.6866 | lr: 3.02e-04 | val_acc: 83.88%
# Epoch  57 | train: 0.6120 | val: 0.6767 | lr: 2.90e-04 | val_acc: 83.58%
# Epoch  58 | train: 0.5810 | val: 0.6659 | lr: 2.77e-04 | val_acc: 83.88%
# Epoch  59 | train: 0.6073 | val: 0.7038 | lr: 2.64e-04 | val_acc: 84.18%
# Epoch  60 | train: 0.5854 | val: 0.6623 | lr: 2.51e-04 | val_acc: 84.18%
# Epoch  61 | train: 0.5734 | val: 0.6764 | lr: 2.37e-04 | val_acc: 84.48%  <- best
# Epoch  62 | train: 0.5625 | val: 0.6529 | lr: 2.24e-04 | val_acc: 84.18%
# Epoch  63 | train: 0.5599 | val: 0.6401 | lr: 2.11e-04 | val_acc: 83.88%
# Epoch  64 | train: 0.5649 | val: 0.6687 | lr: 1.99e-04 | val_acc: 83.88%
# Epoch  65 | train: 0.5344 | val: 0.6300 | lr: 1.86e-04 | val_acc: 83.88%
# Epoch  66 | train: 0.5588 | val: 0.6419 | lr: 1.73e-04 | val_acc: 83.88%
# Epoch  67 | train: 0.5584 | val: 0.6448 | lr: 1.61e-04 | val_acc: 84.18%
# Epoch  68 | train: 0.5559 | val: 0.6120 | lr: 1.49e-04 | val_acc: 84.18%
# Epoch  69 | train: 0.5442 | val: 0.6794 | lr: 1.37e-04 | val_acc: 84.48%
# Epoch  70 | train: 0.5346 | val: 0.6727 | lr: 1.26e-04 | val_acc: 85.37%  <- best
# Epoch  71 | train: 0.5213 | val: 0.6633 | lr: 1.15e-04 | val_acc: 85.67%  <- best
# Epoch  72 | train: 0.5359 | val: 0.6423 | lr: 1.04e-04 | val_acc: 86.27%  <- best
# Epoch  73 | train: 0.5246 | val: 0.6452 | lr: 9.35e-05 | val_acc: 86.27%
# Epoch  74 | train: 0.5207 | val: 0.6500 | lr: 8.36e-05 | val_acc: 86.27%
# Epoch  75 | train: 0.5204 | val: 0.6325 | lr: 7.41e-05 | val_acc: 85.97%
# Epoch  76 | train: 0.5048 | val: 0.6202 | lr: 6.51e-05 | val_acc: 86.57%  <- best
# Epoch  77 | train: 0.5185 | val: 0.6282 | lr: 5.66e-05 | val_acc: 86.57%
# Epoch  78 | train: 0.5068 | val: 0.6148 | lr: 4.87e-05 | val_acc: 86.27%
# Epoch  79 | train: 0.5026 | val: 0.6420 | lr: 4.13e-05 | val_acc: 85.97%
# Epoch  80 | train: 0.4990 | val: 0.6423 | lr: 3.44e-05 | val_acc: 86.57%
# Epoch  81 | train: 0.4969 | val: 0.6240 | lr: 2.82e-05 | val_acc: 86.57%
# Epoch  82 | train: 0.4955 | val: 0.6293 | lr: 2.26e-05 | val_acc: 86.57%
# Epoch  83 | train: 0.5018 | val: 0.6888 | lr: 1.76e-05 | val_acc: 86.57%
# Epoch  84 | train: 0.5148 | val: 0.6369 | lr: 1.32e-05 | val_acc: 86.57%
# Epoch  85 | train: 0.5146 | val: 0.6284 | lr: 9.50e-06 | val_acc: 86.57%
# Epoch  86 | train: 0.5068 | val: 0.6769 | lr: 6.45e-06 | val_acc: 86.57%
# Epoch  87 | train: 0.5002 | val: 0.6334 | lr: 4.07e-06 | val_acc: 86.57%
# Epoch  88 | train: 0.5138 | val: 0.6453 | lr: 2.37e-06 | val_acc: 86.57%
# Epoch  89 | train: 0.4856 | val: 0.6254 | lr: 1.34e-06 | val_acc: 86.27%
# Epoch  90 | train: 0.5001 | val: 0.6242 | lr: 5.00e-04 | val_acc: 86.27%
# Epoch  91 | train: 0.5448 | val: 0.6480 | lr: 5.00e-04 | val_acc: 86.27%
# Epoch  92 | train: 0.5729 | val: 0.5985 | lr: 5.00e-04 | val_acc: 86.27%
# Epoch  93 | train: 0.5682 | val: 0.6318 | lr: 4.99e-04 | val_acc: 86.27%
# Epoch  94 | train: 0.5967 | val: 0.5998 | lr: 4.99e-04 | val_acc: 85.97%
# Epoch  95 | train: 0.5860 | val: 0.6346 | lr: 4.98e-04 | val_acc: 86.27%
# Epoch  96 | train: 0.5823 | val: 0.6486 | lr: 4.97e-04 | val_acc: 87.16%  <- best
# Epoch  97 | train: 0.5812 | val: 0.6348 | lr: 4.96e-04 | val_acc: 87.16%  <- best
# Epoch  98 | train: 0.5591 | val: 0.5889 | lr: 4.95e-04 | val_acc: 87.76%  <- best
# Epoch  99 | train: 0.5889 | val: 0.6660 | lr: 4.93e-04 | val_acc: 88.36%  <- best
# Epoch 100 | train: 0.5426 | val: 0.6276 | lr: 4.91e-04 | val_acc: 87.76%
# Epoch 101 | train: 0.5617 | val: 0.6285 | lr: 4.90e-04 | val_acc: 87.76%
# Epoch 102 | train: 0.5277 | val: 0.6525 | lr: 4.88e-04 | val_acc: 87.46%
# Epoch 103 | train: 0.5509 | val: 0.6432 | lr: 4.86e-04 | val_acc: 87.16%
# Epoch 104 | train: 0.5435 | val: 0.6246 | lr: 4.83e-04 | val_acc: 87.16%
# Epoch 105 | train: 0.5405 | val: 0.6114 | lr: 4.81e-04 | val_acc: 87.46%
# Epoch 106 | train: 0.5392 | val: 0.6155 | lr: 4.78e-04 | val_acc: 87.16%
# Epoch 107 | train: 0.5370 | val: 0.6157 | lr: 4.76e-04 | val_acc: 87.16%
# Epoch 108 | train: 0.5416 | val: 0.5514 | lr: 4.73e-04 | val_acc: 87.16%
# Epoch 109 | train: 0.5474 | val: 0.6201 | lr: 4.70e-04 | val_acc: 87.76%
# Epoch 110 | train: 0.5360 | val: 0.6158 | lr: 4.67e-04 | val_acc: 87.16%
# Epoch 111 | train: 0.5332 | val: 0.6176 | lr: 4.63e-04 | val_acc: 86.87%
# Epoch 112 | train: 0.5230 | val: 0.5930 | lr: 4.60e-04 | val_acc: 87.16%
# Epoch 113 | train: 0.5287 | val: 0.6200 | lr: 4.56e-04 | val_acc: 87.16%
# Epoch 114 | train: 0.5308 | val: 0.5918 | lr: 4.52e-04 | val_acc: 87.46%
# Epoch 115 | train: 0.5221 | val: 0.6238 | lr: 4.48e-04 | val_acc: 87.76%
# Epoch 116 | train: 0.5171 | val: 0.6006 | lr: 4.44e-04 | val_acc: 87.46%
# Epoch 117 | train: 0.5203 | val: 0.6252 | lr: 4.40e-04 | val_acc: 88.36%  <- best
# Epoch 118 | train: 0.4910 | val: 0.6136 | lr: 4.36e-04 | val_acc: 88.66%  <- best
# Epoch 119 | train: 0.5093 | val: 0.6133 | lr: 4.31e-04 | val_acc: 88.36%
# Epoch 120 | train: 0.5406 | val: 0.6036 | lr: 4.27e-04 | val_acc: 88.36%
# Epoch 121 | train: 0.4933 | val: 0.6044 | lr: 4.22e-04 | val_acc: 87.76%
# Epoch 122 | train: 0.4967 | val: 0.6182 | lr: 4.17e-04 | val_acc: 87.76%
# Epoch 123 | train: 0.5003 | val: 0.5646 | lr: 4.13e-04 | val_acc: 88.06%
# Epoch 124 | train: 0.5015 | val: 0.6087 | lr: 4.08e-04 | val_acc: 88.36%
# Epoch 125 | train: 0.4897 | val: 0.5943 | lr: 4.02e-04 | val_acc: 88.06%
# Epoch 126 | train: 0.5048 | val: 0.6336 | lr: 3.97e-04 | val_acc: 87.76%
# Epoch 127 | train: 0.4890 | val: 0.6179 | lr: 3.92e-04 | val_acc: 88.36%
# Epoch 128 | train: 0.4862 | val: 0.6054 | lr: 3.86e-04 | val_acc: 87.76%
# Epoch 129 | train: 0.4889 | val: 0.6318 | lr: 3.81e-04 | val_acc: 87.76%
# Epoch 130 | train: 0.4793 | val: 0.6487 | lr: 3.75e-04 | val_acc: 87.46%
# Epoch 131 | train: 0.4850 | val: 0.5669 | lr: 3.70e-04 | val_acc: 88.06%
# Epoch 132 | train: 0.4734 | val: 0.6125 | lr: 3.64e-04 | val_acc: 87.46%
# Epoch 133 | train: 0.4851 | val: 0.5718 | lr: 3.58e-04 | val_acc: 87.76%
# Epoch 134 | train: 0.4732 | val: 0.6174 | lr: 3.52e-04 | val_acc: 88.06%
# Epoch 135 | train: 0.4843 | val: 0.6096 | lr: 3.46e-04 | val_acc: 87.76%
# Epoch 136 | train: 0.4841 | val: 0.6410 | lr: 3.40e-04 | val_acc: 88.06%
# Epoch 137 | train: 0.4552 | val: 0.6205 | lr: 3.34e-04 | val_acc: 88.66%
# Epoch 138 | train: 0.4512 | val: 0.5735 | lr: 3.28e-04 | val_acc: 88.66%  <- best
# Epoch 139 | train: 0.4458 | val: 0.6745 | lr: 3.21e-04 | val_acc: 88.06%
# Epoch 140 | train: 0.4623 | val: 0.6011 | lr: 3.15e-04 | val_acc: 88.06%
# Epoch 141 | train: 0.4599 | val: 0.6358 | lr: 3.09e-04 | val_acc: 88.36%
# Epoch 142 | train: 0.4361 | val: 0.6643 | lr: 3.02e-04 | val_acc: 88.66%
# Epoch 143 | train: 0.4530 | val: 0.6172 | lr: 2.96e-04 | val_acc: 87.76%
# Epoch 144 | train: 0.4633 | val: 0.6230 | lr: 2.90e-04 | val_acc: 88.06%
# Epoch 145 | train: 0.4637 | val: 0.5991 | lr: 2.83e-04 | val_acc: 88.36%
# Epoch 146 | train: 0.4546 | val: 0.6258 | lr: 2.77e-04 | val_acc: 87.76%
# Epoch 147 | train: 0.4362 | val: 0.6282 | lr: 2.70e-04 | val_acc: 88.06%
# Epoch 148 | train: 0.4623 | val: 0.5597 | lr: 2.64e-04 | val_acc: 88.66%  <- best
# Epoch 149 | train: 0.4448 | val: 0.5766 | lr: 2.57e-04 | val_acc: 88.66%
# Epoch 150 | train: 0.4199 | val: 0.6032 | lr: 2.51e-04 | val_acc: 88.36%
# Epoch 151 | train: 0.4363 | val: 0.5752 | lr: 2.44e-04 | val_acc: 88.96%  <- best
# Epoch 152 | train: 0.4438 | val: 0.5701 | lr: 2.37e-04 | val_acc: 88.06%
# Epoch 153 | train: 0.4451 | val: 0.6036 | lr: 2.31e-04 | val_acc: 88.06%
# Epoch 154 | train: 0.4465 | val: 0.6352 | lr: 2.24e-04 | val_acc: 87.76%
# Epoch 155 | train: 0.4338 | val: 0.5847 | lr: 2.18e-04 | val_acc: 87.76%
# Epoch 156 | train: 0.4339 | val: 0.6231 | lr: 2.11e-04 | val_acc: 87.46%
# Epoch 157 | train: 0.4326 | val: 0.6471 | lr: 2.05e-04 | val_acc: 87.46%
# Epoch 158 | train: 0.4279 | val: 0.6206 | lr: 1.99e-04 | val_acc: 88.06%
# Epoch 159 | train: 0.4191 | val: 0.6056 | lr: 1.92e-04 | val_acc: 88.36%
# Epoch 160 | train: 0.4303 | val: 0.5934 | lr: 1.86e-04 | val_acc: 87.76%
# Epoch 161 | train: 0.4126 | val: 0.5825 | lr: 1.80e-04 | val_acc: 88.36%
# Epoch 162 | train: 0.4253 | val: 0.5884 | lr: 1.73e-04 | val_acc: 88.36%
# Epoch 163 | train: 0.4111 | val: 0.5933 | lr: 1.67e-04 | val_acc: 88.36%
# Epoch 164 | train: 0.4076 | val: 0.5857 | lr: 1.61e-04 | val_acc: 88.96%
# Epoch 165 | train: 0.4057 | val: 0.5927 | lr: 1.55e-04 | val_acc: 88.96%
# Epoch 166 | train: 0.4008 | val: 0.5732 | lr: 1.49e-04 | val_acc: 88.36%
# Epoch 167 | train: 0.4048 | val: 0.6239 | lr: 1.43e-04 | val_acc: 88.06%
# Epoch 168 | train: 0.4140 | val: 0.5741 | lr: 1.37e-04 | val_acc: 88.06%
# Epoch 169 | train: 0.4236 | val: 0.5923 | lr: 1.31e-04 | val_acc: 88.36%
# Epoch 170 | train: 0.4136 | val: 0.5606 | lr: 1.26e-04 | val_acc: 88.06%
# Epoch 171 | train: 0.4073 | val: 0.5980 | lr: 1.20e-04 | val_acc: 88.06%
# Epoch 172 | train: 0.4086 | val: 0.6179 | lr: 1.15e-04 | val_acc: 88.06%
# Epoch 173 | train: 0.4100 | val: 0.6362 | lr: 1.09e-04 | val_acc: 88.06%
# Epoch 174 | train: 0.4028 | val: 0.5879 | lr: 1.04e-04 | val_acc: 88.06%
# Epoch 175 | train: 0.4028 | val: 0.5815 | lr: 9.86e-05 | val_acc: 88.06%
# Epoch 176 | train: 0.3960 | val: 0.6177 | lr: 9.35e-05 | val_acc: 87.76%
# Epoch 177 | train: 0.3991 | val: 0.6474 | lr: 8.85e-05 | val_acc: 87.76%
# Epoch 178 | train: 0.3966 | val: 0.5964 | lr: 8.36e-05 | val_acc: 87.76%
# Epoch 179 | train: 0.3997 | val: 0.6199 | lr: 7.88e-05 | val_acc: 88.06%
# Epoch 180 | train: 0.3994 | val: 0.5917 | lr: 7.41e-05 | val_acc: 88.36%
# Epoch 181 | train: 0.4020 | val: 0.6151 | lr: 6.95e-05 | val_acc: 88.36%
# Epoch 182 | train: 0.3966 | val: 0.5671 | lr: 6.51e-05 | val_acc: 88.06%
# Epoch 183 | train: 0.3996 | val: 0.5615 | lr: 6.08e-05 | val_acc: 88.36%
# Epoch 184 | train: 0.3976 | val: 0.6003 | lr: 5.66e-05 | val_acc: 88.66%
# Epoch 185 | train: 0.3968 | val: 0.6156 | lr: 5.26e-05 | val_acc: 88.36%
# Epoch 186 | train: 0.3978 | val: 0.6229 | lr: 4.87e-05 | val_acc: 88.66%
# Epoch 187 | train: 0.3963 | val: 0.5733 | lr: 4.49e-05 | val_acc: 88.66%
# Epoch 188 | train: 0.3950 | val: 0.6415 | lr: 4.13e-05 | val_acc: 88.96%
# Epoch 189 | train: 0.3971 | val: 0.5267 | lr: 3.78e-05 | val_acc: 89.25%  <- best
# Epoch 190 | train: 0.3954 | val: 0.6121 | lr: 3.44e-05 | val_acc: 88.96%
# Epoch 191 | train: 0.3948 | val: 0.6220 | lr: 3.12e-05 | val_acc: 89.25%
# Epoch 192 | train: 0.3972 | val: 0.6300 | lr: 2.82e-05 | val_acc: 88.96%
# Epoch 193 | train: 0.3965 | val: 0.5824 | lr: 2.53e-05 | val_acc: 88.96%
# Epoch 194 | train: 0.3987 | val: 0.5673 | lr: 2.26e-05 | val_acc: 88.96%
# Epoch 195 | train: 0.3920 | val: 0.5648 | lr: 2.00e-05 | val_acc: 89.25%
# Epoch 196 | train: 0.3916 | val: 0.5878 | lr: 1.76e-05 | val_acc: 89.55%  <- best
# Epoch 197 | train: 0.3940 | val: 0.5181 | lr: 1.53e-05 | val_acc: 89.55%  <- best
# Epoch 198 | train: 0.3949 | val: 0.6074 | lr: 1.32e-05 | val_acc: 89.55%
# Epoch 199 | train: 0.3976 | val: 0.5563 | lr: 1.13e-05 | val_acc: 89.55%
# Epoch 200 | train: 0.3983 | val: 0.5933 | lr: 9.50e-06 | val_acc: 89.55%
# Epoch 201 | train: 0.3942 | val: 0.5966 | lr: 7.89e-06 | val_acc: 89.55%
# Epoch 202 | train: 0.4004 | val: 0.5945 | lr: 6.45e-06 | val_acc: 89.55%
# Epoch 203 | train: 0.3979 | val: 0.6099 | lr: 5.18e-06 | val_acc: 89.55%
# Epoch 204 | train: 0.3989 | val: 0.5665 | lr: 4.07e-06 | val_acc: 89.55%
# Epoch 205 | train: 0.3963 | val: 0.5700 | lr: 3.13e-06 | val_acc: 89.55%
# Epoch 206 | train: 0.3938 | val: 0.5503 | lr: 2.37e-06 | val_acc: 89.85%  <- best
# Epoch 207 | train: 0.3921 | val: 0.5827 | lr: 1.77e-06 | val_acc: 89.85%
# Epoch 208 | train: 0.3970 | val: 0.6464 | lr: 1.34e-06 | val_acc: 89.85%
# Epoch 209 | train: 0.3963 | val: 0.6016 | lr: 1.09e-06 | val_acc: 89.85%
# Epoch 210 | train: 0.3942 | val: 0.5682 | lr: 5.00e-04 | val_acc: 89.85%
# Epoch 211 | train: 0.4043 | val: 0.5835 | lr: 5.00e-04 | val_acc: 89.55%
# Epoch 212 | train: 0.4180 | val: 0.5691 | lr: 5.00e-04 | val_acc: 89.55%
# Epoch 213 | train: 0.4414 | val: 0.5849 | lr: 5.00e-04 | val_acc: 89.55%
# Epoch 214 | train: 0.4820 | val: 0.5739 | lr: 5.00e-04 | val_acc: 89.85%
# Epoch 215 | train: 0.4564 | val: 0.5648 | lr: 4.99e-04 | val_acc: 89.85%
# Epoch 216 | train: 0.4566 | val: 0.6016 | lr: 4.99e-04 | val_acc: 90.75%  <- best
# Epoch 217 | train: 0.5014 | val: 0.5520 | lr: 4.99e-04 | val_acc: 90.75%  <- best
# Epoch 218 | train: 0.5234 | val: 0.5842 | lr: 4.99e-04 | val_acc: 90.15%
# Epoch 219 | train: 0.4847 | val: 0.6306 | lr: 4.98e-04 | val_acc: 90.45%
# Epoch 220 | train: 0.4850 | val: 0.5921 | lr: 4.98e-04 | val_acc: 90.15%
# Epoch 221 | train: 0.4891 | val: 0.5819 | lr: 4.97e-04 | val_acc: 90.15%
# Epoch 222 | train: 0.4624 | val: 0.5990 | lr: 4.97e-04 | val_acc: 89.55%
# Epoch 223 | train: 0.4818 | val: 0.6455 | lr: 4.96e-04 | val_acc: 89.85%
# Epoch 224 | train: 0.4932 | val: 0.6607 | lr: 4.96e-04 | val_acc: 89.85%
# Epoch 225 | train: 0.4740 | val: 0.5622 | lr: 4.95e-04 | val_acc: 89.85%
# Epoch 226 | train: 0.4853 | val: 0.6360 | lr: 4.95e-04 | val_acc: 89.55%
# Epoch 227 | train: 0.4949 | val: 0.6423 | lr: 4.94e-04 | val_acc: 89.55%
# Epoch 228 | train: 0.4985 | val: 0.5941 | lr: 4.93e-04 | val_acc: 88.36%
# Epoch 229 | train: 0.4999 | val: 0.5814 | lr: 4.92e-04 | val_acc: 88.66%
# Epoch 230 | train: 0.5019 | val: 0.6323 | lr: 4.91e-04 | val_acc: 88.36%
# Epoch 231 | train: 0.4843 | val: 0.6389 | lr: 4.91e-04 | val_acc: 88.36%
# Epoch 232 | train: 0.4695 | val: 0.5914 | lr: 4.90e-04 | val_acc: 88.66%
# Epoch 233 | train: 0.4894 | val: 0.5903 | lr: 4.89e-04 | val_acc: 89.25%
# Epoch 234 | train: 0.4949 | val: 0.5841 | lr: 4.88e-04 | val_acc: 89.25%
# Epoch 235 | train: 0.4755 | val: 0.6367 | lr: 4.87e-04 | val_acc: 88.96%
# Epoch 236 | train: 0.4408 | val: 0.5572 | lr: 4.86e-04 | val_acc: 88.96%
# Epoch 237 | train: 0.4412 | val: 0.6142 | lr: 4.85e-04 | val_acc: 88.36%
# Epoch 238 | train: 0.4652 | val: 0.6006 | lr: 4.83e-04 | val_acc: 88.66%
# Epoch 239 | train: 0.4524 | val: 0.6451 | lr: 4.82e-04 | val_acc: 88.36%
# Epoch 240 | train: 0.4805 | val: 0.5994 | lr: 4.81e-04 | val_acc: 88.36%
# Epoch 241 | train: 0.4814 | val: 0.6450 | lr: 4.80e-04 | val_acc: 88.36%
# Epoch 242 | train: 0.4300 | val: 0.5679 | lr: 4.78e-04 | val_acc: 88.66%
# Epoch 243 | train: 0.4750 | val: 0.6052 | lr: 4.77e-04 | val_acc: 88.66%
# Epoch 244 | train: 0.4266 | val: 0.5443 | lr: 4.76e-04 | val_acc: 88.36%
# Epoch 245 | train: 0.4346 | val: 0.5744 | lr: 4.74e-04 | val_acc: 88.66%
# Epoch 246 | train: 0.4666 | val: 0.5878 | lr: 4.73e-04 | val_acc: 88.96%
# Epoch 247 | train: 0.4840 | val: 0.6243 | lr: 4.71e-04 | val_acc: 88.36%
# Epoch 248 | train: 0.4893 | val: 0.5754 | lr: 4.70e-04 | val_acc: 88.36%
# Epoch 249 | train: 0.4538 | val: 0.5823 | lr: 4.68e-04 | val_acc: 88.36%
# Epoch 250 | train: 0.4608 | val: 0.5795 | lr: 4.67e-04 | val_acc: 88.96%
# Epoch 251 | train: 0.4640 | val: 0.6319 | lr: 4.65e-04 | val_acc: 89.55%
# Epoch 252 | train: 0.4596 | val: 0.5978 | lr: 4.63e-04 | val_acc: 88.96%
# Epoch 253 | train: 0.4702 | val: 0.5693 | lr: 4.62e-04 | val_acc: 89.25%
# Epoch 254 | train: 0.4433 | val: 0.5964 | lr: 4.60e-04 | val_acc: 88.36%
# Epoch 255 | train: 0.4649 | val: 0.5973 | lr: 4.58e-04 | val_acc: 88.96%
# Epoch 256 | train: 0.4586 | val: 0.6013 | lr: 4.56e-04 | val_acc: 89.25%
# Epoch 257 | train: 0.4644 | val: 0.6149 | lr: 4.54e-04 | val_acc: 88.96%
# Epoch 258 | train: 0.4806 | val: 0.5835 | lr: 4.52e-04 | val_acc: 88.96%
# Epoch 259 | train: 0.4721 | val: 0.5735 | lr: 4.50e-04 | val_acc: 89.55%
# Epoch 260 | train: 0.4496 | val: 0.5988 | lr: 4.48e-04 | val_acc: 89.55%
# Epoch 261 | train: 0.4786 | val: 0.6263 | lr: 4.46e-04 | val_acc: 90.45%
# Epoch 262 | train: 0.4579 | val: 0.6164 | lr: 4.44e-04 | val_acc: 89.25%
# Epoch 263 | train: 0.4673 | val: 0.6409 | lr: 4.42e-04 | val_acc: 89.85%
# Epoch 264 | train: 0.4693 | val: 0.6280 | lr: 4.40e-04 | val_acc: 88.96%
# Epoch 265 | train: 0.4457 | val: 0.6712 | lr: 4.38e-04 | val_acc: 88.36%
# Epoch 266 | train: 0.4407 | val: 0.6449 | lr: 4.36e-04 | val_acc: 88.06%
# Epoch 267 | train: 0.4874 | val: 0.6196 | lr: 4.34e-04 | val_acc: 88.66%
#
# ------------------------------------------------------------------------------------------
# Early stopping at epoch 267
# ------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------
# Training completed
#
# Best epoch:         217
# Best val loss:      0.5520
# Best val accuracy:  90.75%
#
# Best train distances: d_pos=0.1367 | d_neg=1.4151 | diff=1.2784
# Best val distances:   d_pos=0.4517 | d_neg=1.4126 | diff=0.9609
#
# Data saved in directory: Models\TransformerEncoder_Checkpoints

# %%
model_name = TransformerEncoder.__name__

logs = np.load(f"Models/{model_name}_Checkpoints/training_logs.npz", allow_pickle=True)
train = np.load(f"Models/{model_name}_Checkpoints/train_embeddings.npz", allow_pickle=True)
val   = np.load(f"Models/{model_name}_Checkpoints/val_embeddings.npz", allow_pickle=True)

# %%
best_epoch = int(logs["best_epoch"])
best_val_loss = float(logs["best_val_loss"])
best_val_accuracy = float(logs["best_val_accuracy"])
best_train_dist = logs["best_train_dists"]
best_val_dist = logs["best_val_dists"]

print(f"Best epoch: {best_epoch}")
print(f"Best val loss: {best_val_loss:.4f}")
print(f"Best val accuracy: {best_val_accuracy:.2%}")
print()
print(f"Best train distance:")
print(f"Positive: {best_train_dist[0]}")
print(f"Negative: {best_train_dist[1]}")
print(f"Difference: {best_train_dist[2]}")
print()
print(f"Best validation distance:")
print(f"Positive: {best_val_dist[0]}")
print(f"Negative: {best_val_dist[1]}")
print(f"Difference: {best_val_dist[2]}")
# Out:
# Best epoch: 217
# Best val loss: 0.5520
# Best val accuracy: 90.75%
#
# Best train distance:
# Positive: 0.13672272861003876
# Negative: 1.415126085281372
# Difference: 1.2784032821655273
#
# Best validation distance:
# Positive: 0.4517029821872711
# Negative: 1.4126102924346924
# Difference: 0.9609072804450989

# %%
epochs = logs["epochs"]
train_loss = logs["train_loss"]
val_loss = logs["val_loss"]
val_acc = logs["val_acc"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_loss, mode="lines", name="Train Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_loss, mode="lines", name="Val Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_acc, mode="lines", name="Val Accuracy"))

fig.update_layout(
    title="LSTM Training Metrics over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Values",
    hovermode="x unified"
)

fig.show()

# %%
embeddings = train["last_embeddings"]
labels = train["labels"]
id_to_label = train["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Train Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
embeddings = val["last_embeddings"]
labels = val["labels"]
id_to_label = val["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Validation Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
y_true = logs["best_labels"]
y_pred = logs["best_prediction"]

labels_names = val["id_to_label"]
labels_ids = np.arange(len(labels_names))

cm = confusion_matrix(y_true, y_pred, labels=labels_ids)
cm_norm = cm / cm.sum(axis=1, keepdims=True)

fig = go.Figure(data=go.Heatmap(
    z = cm_norm,
    zmin = 0,
    zmax = 1,
    x = labels_names,
    y = labels_names,
    colorscale="turbo",
    text=cm,
    texttemplate="%{text}",
    hovertemplate="True: %{y}<br>Pred: %{x}<extra></extra>"
))

fig.update_layout(
    title="Prediction in Best Epoch",
    xaxis_title="Predicted label",
    yaxis_title="True label",
    width=1200,
    height=1000,
    margin=dict(l=150, r=50, t=80, b=150)
)

fig.show()

# %%
loss_gap = val_loss - train_loss

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=loss_gap, mode="lines", name="Val Loss - Train Loss"))

fig.update_layout(
    title="Loss Gap over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Loss gap",
    hovermode="x unified"
)

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    labels=labels_ids,
    target_names=labels_names,
    zero_division=0
))
# Out:
#               precision    recall  f1-score   support
#
#   BASKETBALL       1.00      0.92      0.96        13
#          BEE       0.77      0.83      0.80        12
#    BREAKFAST       0.90      0.75      0.82        12
#         CALL       1.00      1.00      1.00         9
#          CAR       0.90      1.00      0.95         9
#        CAT 3       1.00      0.89      0.94         9
#    CHRISTMAS       0.92      0.92      0.92        12
#         DEAF       0.77      0.83      0.80        12
#          DOG       0.87      0.93      0.90        14
#          EAT       0.92      1.00      0.96        12
#      FIREMAN       1.00      0.89      0.94         9
#         FISH       0.89      0.89      0.89         9
#     FOOTBALL       0.90      1.00      0.95         9
#        GREEN       0.90      0.90      0.90        10
#         HEAD       0.90      1.00      0.95         9
#     HOSPITAL       0.90      0.75      0.82        12
#          KID       0.90      1.00      0.95         9
#        LUNCH       0.71      0.83      0.77        12
#          MAN       1.00      1.00      1.00         9
#     MECHANIC       0.92      1.00      0.96        12
#      MORNING       0.82      0.90      0.86        10
#        NIGHT       1.00      0.75      0.86        12
#           NO       0.82      1.00      0.90         9
#         NOON       0.82      0.75      0.78        12
#          RED       0.91      1.00      0.95        10
#        SMILE       1.00      1.00      1.00         9
#      STUDENT       1.00      0.89      0.94         9
#         TRIP       1.00      0.92      0.96        12
#   UNIVERSITY       1.00      0.90      0.95        10
#        VALUE       1.00      0.78      0.88         9
#        WOMAN       1.00      1.00      1.00        10
#          YES       0.90      1.00      0.95         9
#
#     accuracy                           0.91       335
#    macro avg       0.92      0.91      0.91       335
# weighted avg       0.91      0.91      0.91       335

# %%
from sklearn.metrics import recall_score

recalls = recall_score(
    y_true,
    y_pred,
    labels=labels_ids,
    average=None,
    zero_division=0
)

order = np.argsort(recalls)

fig = go.Figure(go.Bar(
    x=recalls[order],
    y=labels_names[order],
    orientation="h"
))

fig.update_layout(
    title="Recall per Class",
    xaxis_title="Recall",
    yaxis_title="Class",
    width=1000,
    height=800,
)

fig.show()

# %%
train_dists_mean = logs["train_dists"]
val_dists_mean = logs["val_dists"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 0], mode="lines", name="Train Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 1], mode="lines", name="Train Negative Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 0], mode="lines", name="Val Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 1], mode="lines", name="Val Negative Distance"))

fig.update_layout(
    title="Embedding Distances over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 2], mode="lines", name="Train Difference"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 2], mode="lines", name="Val Difference"))

fig.update_layout(
    title="Embedding Distances between Positive and Negative Samples over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
lr = logs["lr"]

fig = go.Figure()

fig.add_trace(go.Scatter(x=epochs, y=lr, mode="lines", name="Train Loss"))

fig.update_layout(
    title="Learning Rate over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Learnig Rate",
    hovermode="x unified",
)

fig.show()

# %%
val.close()
train.close()
logs.close()
