# %%
import plotly.graph_objects as go
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import pandas as pd
import plotly.express as px
from sklearn.manifold import TSNE
import colorcet as cc

# %%
# %cd ..
# Out:
# c:\Users\Kayned\Documents\GitHub\LSTM-FAISS-DTW

# %%
from TrainModel.train import training
from Models.LSTM_encoder import LSTMEncoder
training(LSTMEncoder)
# Out:
# Train: 733 videos | Val: 335 videos | Classes: 32
# ------------------------------------------------------------------------------------------
# Model: LSTMEncoder      input= 144      hidden= 256   layers= 2   dropout= 0.4    device= cuda
# Training: epochs= 500    lr= 0.0005    MultiSimilarityLoss: alpha= 2.0 beta= 40.0 base= 0.5
# Batch Train: P = 16 classes x K = 4 = 64 samples
# Batch Val:   P = 16 classes x K = 4 = 64 samples
# ------------------------------------------------------------------------------------------
# Epoch   1 | train: 1.0076 | val: 0.9750 | lr: 4.99e-04 | val_acc: 52.24%  <- best
# Epoch   2 | train: 0.9618 | val: 0.9441 | lr: 4.95e-04 | val_acc: 63.28%  <- best
# Epoch   3 | train: 0.9462 | val: 0.9378 | lr: 4.88e-04 | val_acc: 60.00%
# Epoch   4 | train: 0.9282 | val: 0.9059 | lr: 4.78e-04 | val_acc: 63.88%  <- best
# Epoch   5 | train: 0.9079 | val: 0.8868 | lr: 4.67e-04 | val_acc: 70.15%  <- best
# Epoch   6 | train: 0.8876 | val: 0.9195 | lr: 4.52e-04 | val_acc: 64.18%
# Epoch   7 | train: 0.8984 | val: 0.8846 | lr: 4.36e-04 | val_acc: 66.57%
# Epoch   8 | train: 0.8777 | val: 0.9073 | lr: 4.17e-04 | val_acc: 64.78%
# Epoch   9 | train: 0.8790 | val: 0.8829 | lr: 3.97e-04 | val_acc: 69.85%
# Epoch  10 | train: 0.8618 | val: 0.8600 | lr: 3.75e-04 | val_acc: 71.94%  <- best
# Epoch  11 | train: 0.8693 | val: 0.8648 | lr: 3.52e-04 | val_acc: 69.85%
# Epoch  12 | train: 0.8503 | val: 0.8420 | lr: 3.28e-04 | val_acc: 70.75%
# Epoch  13 | train: 0.8180 | val: 0.8333 | lr: 3.02e-04 | val_acc: 73.13%  <- best
# Epoch  14 | train: 0.8242 | val: 0.8487 | lr: 2.77e-04 | val_acc: 69.85%
# Epoch  15 | train: 0.8203 | val: 0.8197 | lr: 2.51e-04 | val_acc: 74.03%  <- best
# Epoch  16 | train: 0.8087 | val: 0.8156 | lr: 2.24e-04 | val_acc: 74.03%  <- best
# Epoch  17 | train: 0.7900 | val: 0.7918 | lr: 1.99e-04 | val_acc: 75.22%  <- best
# Epoch  18 | train: 0.7742 | val: 0.8063 | lr: 1.73e-04 | val_acc: 76.12%  <- best
# Epoch  19 | train: 0.7743 | val: 0.7828 | lr: 1.49e-04 | val_acc: 74.93%
# Epoch  20 | train: 0.7749 | val: 0.8057 | lr: 1.26e-04 | val_acc: 75.52%
# Epoch  21 | train: 0.7780 | val: 0.7741 | lr: 1.04e-04 | val_acc: 75.22%
# Epoch  22 | train: 0.7817 | val: 0.7940 | lr: 8.36e-05 | val_acc: 75.22%
# Epoch  23 | train: 0.7496 | val: 0.8037 | lr: 6.51e-05 | val_acc: 76.72%  <- best
# Epoch  24 | train: 0.7476 | val: 0.7567 | lr: 4.87e-05 | val_acc: 77.91%  <- best
# Epoch  25 | train: 0.7399 | val: 0.7898 | lr: 3.44e-05 | val_acc: 77.31%
# Epoch  26 | train: 0.7387 | val: 0.7694 | lr: 2.26e-05 | val_acc: 76.42%
# Epoch  27 | train: 0.7265 | val: 0.7956 | lr: 1.32e-05 | val_acc: 76.72%
# Epoch  28 | train: 0.7286 | val: 0.7661 | lr: 6.45e-06 | val_acc: 77.31%
# Epoch  29 | train: 0.7374 | val: 0.7737 | lr: 2.37e-06 | val_acc: 77.31%
# Epoch  30 | train: 0.7188 | val: 0.7731 | lr: 5.00e-04 | val_acc: 77.31%
# Epoch  31 | train: 0.7501 | val: 0.7451 | lr: 5.00e-04 | val_acc: 77.61%
# Epoch  32 | train: 0.7866 | val: 0.7840 | lr: 4.99e-04 | val_acc: 77.91%
# Epoch  33 | train: 0.7805 | val: 0.7426 | lr: 4.97e-04 | val_acc: 77.61%
# Epoch  34 | train: 0.7624 | val: 0.7748 | lr: 4.95e-04 | val_acc: 77.31%
# Epoch  35 | train: 0.7613 | val: 0.7874 | lr: 4.91e-04 | val_acc: 77.31%
# Epoch  36 | train: 0.7675 | val: 0.7622 | lr: 4.88e-04 | val_acc: 77.91%
# Epoch  37 | train: 0.7374 | val: 0.7712 | lr: 4.83e-04 | val_acc: 78.81%  <- best
# Epoch  38 | train: 0.7467 | val: 0.7316 | lr: 4.78e-04 | val_acc: 79.10%  <- best
# Epoch  39 | train: 0.7413 | val: 0.7525 | lr: 4.73e-04 | val_acc: 79.70%  <- best
# Epoch  40 | train: 0.7284 | val: 0.7568 | lr: 4.67e-04 | val_acc: 79.10%
# Epoch  41 | train: 0.6985 | val: 0.7648 | lr: 4.60e-04 | val_acc: 78.81%
# Epoch  42 | train: 0.7215 | val: 0.7382 | lr: 4.52e-04 | val_acc: 78.21%
# Epoch  43 | train: 0.7078 | val: 0.7288 | lr: 4.44e-04 | val_acc: 78.81%
# Epoch  44 | train: 0.7093 | val: 0.7556 | lr: 4.36e-04 | val_acc: 79.40%
# Epoch  45 | train: 0.7044 | val: 0.7252 | lr: 4.27e-04 | val_acc: 79.10%
# Epoch  46 | train: 0.6973 | val: 0.7045 | lr: 4.17e-04 | val_acc: 80.30%  <- best
# Epoch  47 | train: 0.6569 | val: 0.7440 | lr: 4.08e-04 | val_acc: 80.90%  <- best
# Epoch  48 | train: 0.6801 | val: 0.7169 | lr: 3.97e-04 | val_acc: 80.90%  <- best
# Epoch  49 | train: 0.6835 | val: 0.7125 | lr: 3.86e-04 | val_acc: 81.49%  <- best
# Epoch  50 | train: 0.6781 | val: 0.7077 | lr: 3.75e-04 | val_acc: 81.49%  <- best
# Epoch  51 | train: 0.6723 | val: 0.7487 | lr: 3.64e-04 | val_acc: 81.79%  <- best
# Epoch  52 | train: 0.6521 | val: 0.7269 | lr: 3.52e-04 | val_acc: 82.09%  <- best
# Epoch  53 | train: 0.6422 | val: 0.7231 | lr: 3.40e-04 | val_acc: 81.79%
# Epoch  54 | train: 0.6663 | val: 0.6832 | lr: 3.28e-04 | val_acc: 81.49%
# Epoch  55 | train: 0.6635 | val: 0.7504 | lr: 3.15e-04 | val_acc: 81.49%
# Epoch  56 | train: 0.6360 | val: 0.7341 | lr: 3.02e-04 | val_acc: 81.19%
# Epoch  57 | train: 0.6315 | val: 0.6962 | lr: 2.90e-04 | val_acc: 81.49%
# Epoch  58 | train: 0.6018 | val: 0.7029 | lr: 2.77e-04 | val_acc: 81.19%
# Epoch  59 | train: 0.6318 | val: 0.7598 | lr: 2.64e-04 | val_acc: 81.19%
# Epoch  60 | train: 0.6276 | val: 0.7275 | lr: 2.51e-04 | val_acc: 81.49%
# Epoch  61 | train: 0.5788 | val: 0.7332 | lr: 2.37e-04 | val_acc: 81.79%
# Epoch  62 | train: 0.5749 | val: 0.7023 | lr: 2.24e-04 | val_acc: 81.49%
# Epoch  63 | train: 0.5737 | val: 0.6757 | lr: 2.11e-04 | val_acc: 82.69%  <- best
# Epoch  64 | train: 0.5787 | val: 0.7214 | lr: 1.99e-04 | val_acc: 83.88%  <- best
# Epoch  65 | train: 0.5620 | val: 0.6812 | lr: 1.86e-04 | val_acc: 82.99%
# Epoch  66 | train: 0.5955 | val: 0.6808 | lr: 1.73e-04 | val_acc: 82.69%
# Epoch  67 | train: 0.5867 | val: 0.7127 | lr: 1.61e-04 | val_acc: 82.69%
# Epoch  68 | train: 0.5606 | val: 0.6719 | lr: 1.49e-04 | val_acc: 82.39%
# Epoch  69 | train: 0.5724 | val: 0.7480 | lr: 1.37e-04 | val_acc: 82.39%
# Epoch  70 | train: 0.5509 | val: 0.7016 | lr: 1.26e-04 | val_acc: 82.09%
# Epoch  71 | train: 0.5485 | val: 0.6774 | lr: 1.15e-04 | val_acc: 82.09%
# Epoch  72 | train: 0.5619 | val: 0.7076 | lr: 1.04e-04 | val_acc: 82.09%
# Epoch  73 | train: 0.5367 | val: 0.6690 | lr: 9.35e-05 | val_acc: 82.99%
# Epoch  74 | train: 0.5410 | val: 0.7129 | lr: 8.36e-05 | val_acc: 82.99%
# Epoch  75 | train: 0.5411 | val: 0.6827 | lr: 7.41e-05 | val_acc: 82.99%
# Epoch  76 | train: 0.5286 | val: 0.6571 | lr: 6.51e-05 | val_acc: 82.99%
# Epoch  77 | train: 0.5282 | val: 0.6614 | lr: 5.66e-05 | val_acc: 82.99%
# Epoch  78 | train: 0.5289 | val: 0.6526 | lr: 4.87e-05 | val_acc: 83.28%
# Epoch  79 | train: 0.5275 | val: 0.6911 | lr: 4.13e-05 | val_acc: 83.28%
# Epoch  80 | train: 0.5167 | val: 0.6678 | lr: 3.44e-05 | val_acc: 83.58%
# Epoch  81 | train: 0.5328 | val: 0.6471 | lr: 2.82e-05 | val_acc: 83.58%
# Epoch  82 | train: 0.5194 | val: 0.6677 | lr: 2.26e-05 | val_acc: 83.58%
# Epoch  83 | train: 0.5198 | val: 0.7366 | lr: 1.76e-05 | val_acc: 83.58%
# Epoch  84 | train: 0.5302 | val: 0.6825 | lr: 1.32e-05 | val_acc: 82.99%
# Epoch  85 | train: 0.5316 | val: 0.6806 | lr: 9.50e-06 | val_acc: 82.99%
# Epoch  86 | train: 0.5258 | val: 0.6950 | lr: 6.45e-06 | val_acc: 83.28%
# Epoch  87 | train: 0.5367 | val: 0.6949 | lr: 4.07e-06 | val_acc: 83.28%
# Epoch  88 | train: 0.5270 | val: 0.6675 | lr: 2.37e-06 | val_acc: 83.28%
# Epoch  89 | train: 0.5199 | val: 0.6899 | lr: 1.34e-06 | val_acc: 83.28%
# Epoch  90 | train: 0.5206 | val: 0.6384 | lr: 5.00e-04 | val_acc: 83.28%
# Epoch  91 | train: 0.5787 | val: 0.7193 | lr: 5.00e-04 | val_acc: 83.58%
# Epoch  92 | train: 0.5970 | val: 0.6393 | lr: 5.00e-04 | val_acc: 83.28%
# Epoch  93 | train: 0.5906 | val: 0.6832 | lr: 4.99e-04 | val_acc: 82.99%
# Epoch  94 | train: 0.6012 | val: 0.6330 | lr: 4.99e-04 | val_acc: 83.58%
# Epoch  95 | train: 0.6180 | val: 0.6626 | lr: 4.98e-04 | val_acc: 83.88%  <- best
# Epoch  96 | train: 0.5953 | val: 0.6812 | lr: 4.97e-04 | val_acc: 83.88%
# Epoch  97 | train: 0.5744 | val: 0.6875 | lr: 4.96e-04 | val_acc: 83.88%
# Epoch  98 | train: 0.5686 | val: 0.6094 | lr: 4.95e-04 | val_acc: 83.88%  <- best
# Epoch  99 | train: 0.6144 | val: 0.7013 | lr: 4.93e-04 | val_acc: 84.18%  <- best
# Epoch 100 | train: 0.5903 | val: 0.6724 | lr: 4.91e-04 | val_acc: 83.58%
# Epoch 101 | train: 0.5891 | val: 0.6765 | lr: 4.90e-04 | val_acc: 83.58%
# Epoch 102 | train: 0.5491 | val: 0.7015 | lr: 4.88e-04 | val_acc: 83.58%
# Epoch 103 | train: 0.5585 | val: 0.6950 | lr: 4.86e-04 | val_acc: 83.58%
# Epoch 104 | train: 0.5504 | val: 0.6714 | lr: 4.83e-04 | val_acc: 83.28%
# Epoch 105 | train: 0.5837 | val: 0.7041 | lr: 4.81e-04 | val_acc: 82.99%
# Epoch 106 | train: 0.5938 | val: 0.6474 | lr: 4.78e-04 | val_acc: 83.28%
# Epoch 107 | train: 0.5741 | val: 0.6578 | lr: 4.76e-04 | val_acc: 82.99%
# Epoch 108 | train: 0.5709 | val: 0.5875 | lr: 4.73e-04 | val_acc: 83.58%
# Epoch 109 | train: 0.5586 | val: 0.6642 | lr: 4.70e-04 | val_acc: 83.28%
# Epoch 110 | train: 0.5434 | val: 0.6693 | lr: 4.67e-04 | val_acc: 83.58%
# Epoch 111 | train: 0.5555 | val: 0.6547 | lr: 4.63e-04 | val_acc: 84.18%  <- best
# Epoch 112 | train: 0.5745 | val: 0.6383 | lr: 4.60e-04 | val_acc: 84.48%  <- best
# Epoch 113 | train: 0.5435 | val: 0.6442 | lr: 4.56e-04 | val_acc: 83.88%
# Epoch 114 | train: 0.5490 | val: 0.6263 | lr: 4.52e-04 | val_acc: 83.88%
# Epoch 115 | train: 0.5662 | val: 0.6728 | lr: 4.48e-04 | val_acc: 83.88%
# Epoch 116 | train: 0.5358 | val: 0.6579 | lr: 4.44e-04 | val_acc: 84.48%
# Epoch 117 | train: 0.5316 | val: 0.7272 | lr: 4.40e-04 | val_acc: 84.48%
# Epoch 118 | train: 0.5230 | val: 0.6464 | lr: 4.36e-04 | val_acc: 84.48%
# Epoch 119 | train: 0.5447 | val: 0.6756 | lr: 4.31e-04 | val_acc: 84.78%  <- best
# Epoch 120 | train: 0.5498 | val: 0.6425 | lr: 4.27e-04 | val_acc: 84.48%
# Epoch 121 | train: 0.5283 | val: 0.6400 | lr: 4.22e-04 | val_acc: 84.48%
# Epoch 122 | train: 0.5418 | val: 0.7139 | lr: 4.17e-04 | val_acc: 84.48%
# Epoch 123 | train: 0.5178 | val: 0.6346 | lr: 4.13e-04 | val_acc: 84.18%
# Epoch 124 | train: 0.5299 | val: 0.6579 | lr: 4.08e-04 | val_acc: 84.48%
# Epoch 125 | train: 0.4947 | val: 0.6640 | lr: 4.02e-04 | val_acc: 84.18%
# Epoch 126 | train: 0.5247 | val: 0.6506 | lr: 3.97e-04 | val_acc: 83.58%
# Epoch 127 | train: 0.5197 | val: 0.6626 | lr: 3.92e-04 | val_acc: 84.18%
# Epoch 128 | train: 0.5101 | val: 0.6642 | lr: 3.86e-04 | val_acc: 84.48%
# Epoch 129 | train: 0.4994 | val: 0.6927 | lr: 3.81e-04 | val_acc: 84.48%
# Epoch 130 | train: 0.4952 | val: 0.6687 | lr: 3.75e-04 | val_acc: 84.48%
# Epoch 131 | train: 0.5038 | val: 0.6132 | lr: 3.70e-04 | val_acc: 84.18%
# Epoch 132 | train: 0.5039 | val: 0.6991 | lr: 3.64e-04 | val_acc: 84.48%
# Epoch 133 | train: 0.5003 | val: 0.6437 | lr: 3.58e-04 | val_acc: 84.78%  <- best
# Epoch 134 | train: 0.4915 | val: 0.6535 | lr: 3.52e-04 | val_acc: 84.18%
# Epoch 135 | train: 0.4853 | val: 0.6370 | lr: 3.46e-04 | val_acc: 84.48%
# Epoch 136 | train: 0.4946 | val: 0.6875 | lr: 3.40e-04 | val_acc: 84.18%
# Epoch 137 | train: 0.4727 | val: 0.6756 | lr: 3.34e-04 | val_acc: 83.88%
# Epoch 138 | train: 0.4960 | val: 0.6575 | lr: 3.28e-04 | val_acc: 83.58%
# Epoch 139 | train: 0.4965 | val: 0.7016 | lr: 3.21e-04 | val_acc: 84.18%
# Epoch 140 | train: 0.4863 | val: 0.6607 | lr: 3.15e-04 | val_acc: 84.78%
# Epoch 141 | train: 0.4785 | val: 0.6924 | lr: 3.09e-04 | val_acc: 84.48%
# Epoch 142 | train: 0.4679 | val: 0.6583 | lr: 3.02e-04 | val_acc: 83.58%
# Epoch 143 | train: 0.4996 | val: 0.6490 | lr: 2.96e-04 | val_acc: 84.48%
# Epoch 144 | train: 0.4708 | val: 0.6367 | lr: 2.90e-04 | val_acc: 84.48%
# Epoch 145 | train: 0.4907 | val: 0.7116 | lr: 2.83e-04 | val_acc: 83.88%
# Epoch 146 | train: 0.5012 | val: 0.6736 | lr: 2.77e-04 | val_acc: 83.88%
# Epoch 147 | train: 0.4644 | val: 0.6585 | lr: 2.70e-04 | val_acc: 84.18%
# Epoch 148 | train: 0.4846 | val: 0.6190 | lr: 2.64e-04 | val_acc: 84.18%
# Epoch 149 | train: 0.4870 | val: 0.6575 | lr: 2.57e-04 | val_acc: 84.78%
# Epoch 150 | train: 0.4464 | val: 0.6364 | lr: 2.51e-04 | val_acc: 85.07%  <- best
# Epoch 151 | train: 0.4627 | val: 0.6507 | lr: 2.44e-04 | val_acc: 85.07%
# Epoch 152 | train: 0.4658 | val: 0.6497 | lr: 2.37e-04 | val_acc: 85.07%
# Epoch 153 | train: 0.4514 | val: 0.6337 | lr: 2.31e-04 | val_acc: 85.07%  <- best
# Epoch 154 | train: 0.4316 | val: 0.6798 | lr: 2.24e-04 | val_acc: 84.78%
# Epoch 155 | train: 0.4498 | val: 0.6960 | lr: 2.18e-04 | val_acc: 84.78%
# Epoch 156 | train: 0.4455 | val: 0.6302 | lr: 2.11e-04 | val_acc: 85.37%  <- best
# Epoch 157 | train: 0.4434 | val: 0.6878 | lr: 2.05e-04 | val_acc: 84.78%
# Epoch 158 | train: 0.4303 | val: 0.6939 | lr: 1.99e-04 | val_acc: 84.78%
# Epoch 159 | train: 0.4439 | val: 0.6647 | lr: 1.92e-04 | val_acc: 84.48%
# Epoch 160 | train: 0.4284 | val: 0.6578 | lr: 1.86e-04 | val_acc: 83.88%
# Epoch 161 | train: 0.4498 | val: 0.6287 | lr: 1.80e-04 | val_acc: 83.58%
# Epoch 162 | train: 0.4489 | val: 0.6415 | lr: 1.73e-04 | val_acc: 83.88%
# Epoch 163 | train: 0.4242 | val: 0.6985 | lr: 1.67e-04 | val_acc: 83.88%
# Epoch 164 | train: 0.4221 | val: 0.6615 | lr: 1.61e-04 | val_acc: 83.58%
# Epoch 165 | train: 0.4236 | val: 0.6644 | lr: 1.55e-04 | val_acc: 83.58%
# Epoch 166 | train: 0.4192 | val: 0.6525 | lr: 1.49e-04 | val_acc: 84.48%
# Epoch 167 | train: 0.4339 | val: 0.6986 | lr: 1.43e-04 | val_acc: 84.18%
# Epoch 168 | train: 0.4309 | val: 0.6191 | lr: 1.37e-04 | val_acc: 84.18%
# Epoch 169 | train: 0.4268 | val: 0.6454 | lr: 1.31e-04 | val_acc: 84.48%
# Epoch 170 | train: 0.4267 | val: 0.6588 | lr: 1.26e-04 | val_acc: 84.48%
# Epoch 171 | train: 0.4211 | val: 0.6998 | lr: 1.20e-04 | val_acc: 84.48%
# Epoch 172 | train: 0.4309 | val: 0.6900 | lr: 1.15e-04 | val_acc: 84.18%
# Epoch 173 | train: 0.4295 | val: 0.6455 | lr: 1.09e-04 | val_acc: 84.18%
# Epoch 174 | train: 0.4133 | val: 0.6368 | lr: 1.04e-04 | val_acc: 84.18%
# Epoch 175 | train: 0.4181 | val: 0.6608 | lr: 9.86e-05 | val_acc: 84.18%
# Epoch 176 | train: 0.4055 | val: 0.6611 | lr: 9.35e-05 | val_acc: 84.18%
# Epoch 177 | train: 0.4251 | val: 0.6219 | lr: 8.85e-05 | val_acc: 83.88%
# Epoch 178 | train: 0.4163 | val: 0.6152 | lr: 8.36e-05 | val_acc: 83.88%
# Epoch 179 | train: 0.4126 | val: 0.6284 | lr: 7.88e-05 | val_acc: 84.78%
# Epoch 180 | train: 0.4186 | val: 0.6715 | lr: 7.41e-05 | val_acc: 84.48%
# Epoch 181 | train: 0.4152 | val: 0.7082 | lr: 6.95e-05 | val_acc: 84.48%
# Epoch 182 | train: 0.4161 | val: 0.7210 | lr: 6.51e-05 | val_acc: 84.78%
# Epoch 183 | train: 0.4285 | val: 0.6436 | lr: 6.08e-05 | val_acc: 84.48%
# Epoch 184 | train: 0.4089 | val: 0.6347 | lr: 5.66e-05 | val_acc: 84.78%
# Epoch 185 | train: 0.4108 | val: 0.6830 | lr: 5.26e-05 | val_acc: 84.48%
# Epoch 186 | train: 0.4255 | val: 0.6724 | lr: 4.87e-05 | val_acc: 84.48%
# Epoch 187 | train: 0.4152 | val: 0.6344 | lr: 4.49e-05 | val_acc: 84.18%
# Epoch 188 | train: 0.4089 | val: 0.6618 | lr: 4.13e-05 | val_acc: 84.48%
# Epoch 189 | train: 0.4156 | val: 0.6461 | lr: 3.78e-05 | val_acc: 84.18%
# Epoch 190 | train: 0.4077 | val: 0.6849 | lr: 3.44e-05 | val_acc: 84.18%
# Epoch 191 | train: 0.4157 | val: 0.6532 | lr: 3.12e-05 | val_acc: 83.88%
# Epoch 192 | train: 0.4109 | val: 0.6511 | lr: 2.82e-05 | val_acc: 83.88%
# Epoch 193 | train: 0.4067 | val: 0.6869 | lr: 2.53e-05 | val_acc: 83.88%
# Epoch 194 | train: 0.4094 | val: 0.6678 | lr: 2.26e-05 | val_acc: 83.88%
# Epoch 195 | train: 0.4059 | val: 0.6342 | lr: 2.00e-05 | val_acc: 83.88%
# Epoch 196 | train: 0.4077 | val: 0.6196 | lr: 1.76e-05 | val_acc: 84.18%
# Epoch 197 | train: 0.4080 | val: 0.6394 | lr: 1.53e-05 | val_acc: 84.18%
# Epoch 198 | train: 0.4067 | val: 0.7063 | lr: 1.32e-05 | val_acc: 83.88%
# Epoch 199 | train: 0.4093 | val: 0.6337 | lr: 1.13e-05 | val_acc: 83.88%
# Epoch 200 | train: 0.4046 | val: 0.6572 | lr: 9.50e-06 | val_acc: 84.18%
# Epoch 201 | train: 0.4060 | val: 0.7040 | lr: 7.89e-06 | val_acc: 84.18%
# Epoch 202 | train: 0.4133 | val: 0.6762 | lr: 6.45e-06 | val_acc: 84.18%
# Epoch 203 | train: 0.4119 | val: 0.6772 | lr: 5.18e-06 | val_acc: 84.18%
# Epoch 204 | train: 0.4122 | val: 0.6360 | lr: 4.07e-06 | val_acc: 84.18%
# Epoch 205 | train: 0.4189 | val: 0.6607 | lr: 3.13e-06 | val_acc: 84.48%
# Epoch 206 | train: 0.4062 | val: 0.6610 | lr: 2.37e-06 | val_acc: 84.48%
#
# ------------------------------------------------------------------------------------------
# Early stopping at epoch 206
# ------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------
# Training completed
#
# Best epoch:         156
# Best val loss:      0.6302
# Best val accuracy:  85.37%
#
# Best train distances: d_pos=0.2363 | d_neg=1.4255 | diff=1.1891
# Best val distances:   d_pos=0.5540 | d_neg=1.4246 | diff=0.8707
#
# Data saved in directory: Models\LSTMEncoder_Checkpoints

# %%
model_name = LSTMEncoder.__name__

logs = np.load(f"Models/{model_name}_Checkpoints/training_logs.npz", allow_pickle=True)
train = np.load(f"Models/{model_name}_Checkpoints/train_embeddings.npz", allow_pickle=True)
val   = np.load(f"Models/{model_name}_Checkpoints/val_embeddings.npz", allow_pickle=True)

# %%
best_epoch = int(logs["best_epoch"])
best_val_loss = float(logs["best_val_loss"])
best_val_accuracy = float(logs["best_val_accuracy"])
best_train_dist = logs["best_train_dists"]
best_val_dist = logs["best_val_dists"]

print(f"Best epoch: {best_epoch}")
print(f"Best val loss: {best_val_loss:.4f}")
print(f"Best val accuracy: {best_val_accuracy:.2%}")
print()
print(f"Best train distance:")
print(f"Positive: {best_train_dist[0]}")
print(f"Negative: {best_train_dist[1]}")
print(f"Difference: {best_train_dist[2]}")
print()
print(f"Best validation distance:")
print(f"Positive: {best_val_dist[0]}")
print(f"Negative: {best_val_dist[1]}")
print(f"Difference: {best_val_dist[2]}")
# Out:
# Best epoch: 156
# Best val loss: 0.6302
# Best val accuracy: 85.37%
#
# Best train distance:
# Positive: 0.2363445907831192
# Negative: 1.425464391708374
# Difference: 1.189119815826416
#
# Best validation distance:
# Positive: 0.5539536476135254
# Negative: 1.424633264541626
# Difference: 0.8706795573234558

# %%
epochs = logs["epochs"]
train_loss = logs["train_loss"]
val_loss = logs["val_loss"]
val_acc = logs["val_acc"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_loss, mode="lines", name="Train Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_loss, mode="lines", name="Val Loss"))
fig.add_trace(go.Scatter(x=epochs, y=val_acc, mode="lines", name="Val Accuracy"))

fig.update_layout(
    title="LSTM Training Metrics over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Values",
    hovermode="x unified"
)

fig.show()

# %%
embeddings = train["last_embeddings"]
labels = train["labels"]
id_to_label = train["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Train Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
embeddings = val["last_embeddings"]
labels = val["labels"]
id_to_label = val["id_to_label"]

class_names = [id_to_label[label] for label in labels]

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

embeddings_2d = tsne.fit_transform(embeddings)

df = pd.DataFrame({
    "TSNE1": embeddings_2d[:, 0],
    "TSNE2": embeddings_2d[:, 1],
    "Class": class_names
})

palette_32 = cc.glasbey[:32]

fig = px.scatter(
    df,
    x="TSNE1",
    y="TSNE2",
    color="Class",
    title="t-SNE of Validation Embeddings",
    width=1000,
    height=1000,
    color_discrete_sequence=palette_32
)

fig.show()

# %%
y_true = logs["best_labels"]
y_pred = logs["best_prediction"]

labels_names = val["id_to_label"]
labels_ids = np.arange(len(labels_names))

cm = confusion_matrix(y_true, y_pred, labels=labels_ids)
cm_norm = cm / cm.sum(axis=1, keepdims=True)

fig = go.Figure(data=go.Heatmap(
    z = cm_norm,
    zmin = 0,
    zmax = 1,
    x = labels_names,
    y = labels_names,
    colorscale="turbo",
    text=cm,
    texttemplate="%{text}",
    hovertemplate="True: %{y}<br>Pred: %{x}<extra></extra>"
))

fig.update_layout(
    title="Prediction in Best Epoch",
    xaxis_title="Predicted label",
    yaxis_title="True label",
    width=1200,
    height=1000,
    margin=dict(l=150, r=50, t=80, b=150)
)

fig.show()

# %%
loss_gap = val_loss - train_loss

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=loss_gap, mode="lines", name="Val Loss - Train Loss"))

fig.update_layout(
    title="Loss Gap over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Loss gap",
    hovermode="x unified"
)

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    labels=labels_ids,
    target_names=labels_names,
    zero_division=0
))
# Out:
#               precision    recall  f1-score   support
#
#   BASKETBALL       1.00      0.69      0.82        13
#          BEE       0.82      0.75      0.78        12
#    BREAKFAST       0.71      0.83      0.77        12
#         CALL       0.89      0.89      0.89         9
#          CAR       0.90      1.00      0.95         9
#        CAT 3       0.88      0.78      0.82         9
#    CHRISTMAS       0.89      0.67      0.76        12
#         DEAF       0.92      0.92      0.92        12
#          DOG       0.76      0.93      0.84        14
#          EAT       0.92      0.92      0.92        12
#      FIREMAN       1.00      0.89      0.94         9
#         FISH       0.88      0.78      0.82         9
#     FOOTBALL       1.00      1.00      1.00         9
#        GREEN       0.82      0.90      0.86        10
#         HEAD       0.82      1.00      0.90         9
#     HOSPITAL       0.82      0.75      0.78        12
#          KID       0.82      1.00      0.90         9
#        LUNCH       0.80      0.67      0.73        12
#          MAN       0.78      0.78      0.78         9
#     MECHANIC       1.00      1.00      1.00        12
#      MORNING       0.90      0.90      0.90        10
#        NIGHT       0.90      0.75      0.82        12
#           NO       0.70      0.78      0.74         9
#         NOON       0.69      0.75      0.72        12
#          RED       0.91      1.00      0.95        10
#        SMILE       0.75      1.00      0.86         9
#      STUDENT       0.88      0.78      0.82         9
#         TRIP       1.00      0.92      0.96        12
#   UNIVERSITY       0.80      0.80      0.80        10
#        VALUE       1.00      0.78      0.88         9
#        WOMAN       0.90      0.90      0.90        10
#          YES       0.75      1.00      0.86         9
#
#     accuracy                           0.85       335
#    macro avg       0.86      0.86      0.86       335
# weighted avg       0.86      0.85      0.85       335

# %%
from sklearn.metrics import recall_score

recalls = recall_score(
    y_true,
    y_pred,
    labels=labels_ids,
    average=None,
    zero_division=0
)

order = np.argsort(recalls)

fig = go.Figure(go.Bar(
    x=recalls[order],
    y=labels_names[order],
    orientation="h"
))

fig.update_layout(
    title="Recall per Class",
    xaxis_title="Recall",
    yaxis_title="Class",
    width=1000,
    height=800,
)

fig.show()

# %%
train_dists_mean = logs["train_dists"]
val_dists_mean = logs["val_dists"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 0], mode="lines", name="Train Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 1], mode="lines", name="Train Negative Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 0], mode="lines", name="Val Positive Distance"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 1], mode="lines", name="Val Negative Distance"))

fig.update_layout(
    title="Embedding Distances over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=epochs, y=train_dists_mean[:, 2], mode="lines", name="Train Difference"))
fig.add_trace(go.Scatter(x=epochs, y=val_dists_mean[:, 2], mode="lines", name="Val Difference"))

fig.update_layout(
    title="Embedding Distances between Positive and Negative Samples over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Distance",
    hovermode="x unified",
)

fig.show()

# %%
lr = logs["lr"]

fig = go.Figure()

fig.add_trace(go.Scatter(x=epochs, y=lr, mode="lines", name="Train Loss"))

fig.update_layout(
    title="Learning Rate over Epochs",
    xaxis_title="Epochs",
    yaxis_title="Learnig Rate",
    hovermode="x unified",
)

fig.show()

# %%
val.close()
train.close()
logs.close()
