# %%
# %cd ..
import os
import numpy as np
from pathlib import Path
from Recognition.build_faiss_db import build_index_from_npz, build_index_from_videos
from Models.Transformer_encoder import TransformerEncoder
# Out:
# c:\Users\mjane\Documents\GitHub\LSTM-FAISS-DTW
# c:\Users\mjane\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# npz
model = TransformerEncoder
model_name = model.__name__

faiss_db_dir = os.path.join("Recognition", f"{model_name}_db_base")
os.makedirs(faiss_db_dir, exist_ok=True)
faiss_index_path = os.path.join(faiss_db_dir, "index.faiss")
faiss_labels_path = os.path.join(faiss_db_dir, "index_labels.npz")

data = Path(f"Models/{model_name}_Checkpoints/train_embeddings.npz")

build_index_from_npz(data, output_dir= Path(faiss_db_dir))
# Out:
# FAISS index built from 733 embeddings -> Recognition\TransformerEncoder_db_base\index.faiss
# Labels saved -> Recognition\TransformerEncoder_db_base\index_labels.npz

# %%
# videos

dataset_path = Path("Dataset_custom")

model = TransformerEncoder
model_name = model.__name__

faiss_db_dir = os.path.join("Recognition", f"{model_name}_db_custom")
os.makedirs(faiss_db_dir, exist_ok=True)
faiss_index_path = os.path.join(faiss_db_dir, "index.faiss")
faiss_labels_path = os.path.join(faiss_db_dir, "index_labels.npz")

build_index_from_videos(dataset_path, output_dir=Path(faiss_db_dir))
# Out:
# [build_faiss_db] Found 6 classes: ['SKORA', 'SKROMNY', 'SKRZYPCE', 'SLAD', 'SLISKO', 'WIES']
# [build_faiss_db] Loading encoder from: Models\TransformerEncoder_Checkpoints\best_encoder.pt (device=cpu)
#
#   Video processing 'SKORA' (1)...
#     skora.mp4: OK  embedding shape=(1, 64)
#
#   Video processing 'SKROMNY' (1)...
#     skromny.mp4: OK  embedding shape=(1, 64)
#
#   Video processing 'SKRZYPCE' (1)...
#     skrzypce.mp4: OK  embedding shape=(1, 64)
#
#   Video processing 'SLAD' (1)...
#     slad.mp4: OK  embedding shape=(1, 64)
#
#   Video processing 'SLISKO' (1)...
#     slisko.mp4: OK  embedding shape=(1, 64)
#
#   Video processing 'WIES' (1)...
#     wies .mp4: OK  embedding shape=(1, 64)
#
# [build_faiss_db] Generated 6 embeddings from 6 classes.
# FAISS index built from 6 embeddings -> Recognition\TransformerEncoder_db_custom\index.faiss
# Labels saved -> Recognition\TransformerEncoder_db_custom\index_labels.npz
