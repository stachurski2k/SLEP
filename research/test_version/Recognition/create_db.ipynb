# %%
# %cd ..
from pathlib import Path
from Recognition.build_faiss_db import build_index_from_npz, build_index_from_videos
from Models.Transformer_encoder import TransformerEncoder

# Choose model (e.g. TransformerEncoder, LSTMEncoder, etc.)
MODEL = TransformerEncoder
# Out:
# c:\Users\mjane\Documents\GitHub\LSTM-FAISS-DTW
# c:\Users\mjane\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# Build FAISS index from npz embeddings
build_index_from_npz(model_cls=MODEL)
# Out:
# FAISS index built from 733 embeddings -> Recognition\TransformerEncoder_db_base\index.faiss
# Labels saved -> Recognition\TransformerEncoder_db_base\index_labels.npz

# %%
# Build FAISS index directly from video dataset
build_index_from_videos(dataset_dir=Path("Dataset_custom"), model_cls=MODEL)
# Out:
# [build_faiss_db] Found 10 classes
# [build_faiss_db] Loading encoder from: Models\TransformerEncoder_Checkpoints\best_encoder.pt (device=cpu)
#
#   Video processing 'BOOK' (1)...
#     4195318114915252-BOOK.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'COME' (1)...
#     0165763043403353-COME.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'DRINK' (1)...
#     3150362992415996-DRINK.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'GO' (1)...
#     2290456408074184-GO.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'HOME' (1)...
#     4586501986373326-HOME.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'ME' (1)...
#     059398641585320267-ME.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'READ' (1)...
#     825397870603666-READ.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'SLEEP' (1)...
#     2139029309275231-SLEEP.mp4: OK embedding shape=(1, 64)
#
#   Video processing 'WORK' (1)...
# ...
